# %%
# task1
class Student:
    def __init__(self,name,cg,credit=9,dept='CSE'):
        self.name=name;self.cg=cg;self.credit=credit;self.dept=dept;self.type=None
        self.con=None
    def checkScholarshipEligibility(self):
        if self.credit>10:
            pass
        else:
            self.type='No scholarship'
        if self.cg>=3.7:
            self.type='Merit-based scholarship'
        elif 3.5<=self.cg<=3.7:
            self.type='Need-basedscholarship'

        # if self.cg<=3.5 and self.credit<10:
        #     self.con='not eligible'
        #     if self.con=='not eligible':
        #         self.type='scholarship'
        #     else:
        #         self.type='no scholarship'
        if self.cg>=3.5 and self.credit<10:
            self.con='not eligible'
        if self.cg>=3.5 and self.credit>10:
            self.con='eligible'
        print(f'{self.name} is {self.con} for {self.type}')
    def showDetails(self):
        print(f'Name: {self.name}\nDepartment: {self.dept}\nCGPA: {self.cg}')
        print(f'Number of Credits: {self.credit}\nScholarship Status: {self.type}')
print('--------------------------')
std1 = Student("Alif", 3.99, 12)
print('--------------------------')
std1.checkScholarshipEligibility()
print('--------------------------')
std1.showDetails()
print('--------------------------')
std2 = Student("Mim", 3.4)
std3 = Student("Henry", 3.5, 15,"BBA")
print('--------------------------')
std2.checkScholarshipEligibility()
print('--------------------------')
std3.checkScholarshipEligibility()
print('--------------------------')
std2.showDetails()
print('--------------------------')
std3.showDetails()
print('--------------------------')
std4 = Student("Bob", 4.0, 6, "CSE")
print('--------------------------')
std4.checkScholarshipEligibility()
print('--------------------------')
std4.showDetails()
# Out:
# --------------------------
# --------------------------
# Alif is eligible for Merit-based scholarship
# --------------------------
# Name: Alif
# Department: CSE
# CGPA: 3.99
# Number of Credits: 12
# Scholarship Status: Merit-based scholarship
# --------------------------
# --------------------------
# Mim is None for No scholarship
# --------------------------
# Henry is eligible for Need-basedscholarship
# --------------------------
# Name: Mim
# Department: CSE
# CGPA: 3.4
# Number of Credits: 9
# Scholarship Status: No scholarship
# --------------------------
# Name: Henry
# Department: BBA
# CGPA: 3.5
# Number of Credits: 15
# Scholarship Status: Need-basedscholarship
# --------------------------
# --------------------------
# Bob is not eligible for Merit-based scholarship
# --------------------------
# Name: Bob
# Department: CSE
# CGPA: 4.0
# Number of Credits: 6
# Scholarship Status: Merit-based scholarship

# %%
class Foodie:
    def __init__(self,name):
        self.name=name;self.total=0
    def show_orders(self):
        print(f'{self.name} has {self.amount} item(s) in the cart.')
        print(f'Total spent: {self.sum}')
    def pay_tips(self,tip):
        self.total+=tip
menu = {'Chicken Lollipop':15,'Beef Nugget':20,'Americano':180,'Red Velvet':150,'Prawn Tempura':80,'Saute Veg':200}

f1 = Foodie('Frodo')
print(f1.show_orders())
print('1----------------------')
f1.order('Chicken Lollipop-3','Beef Nugget-6','Americano-1')
print('2----------------------')
print(f1.show_orders())
print('3----------------------')
f1.order('Red Velvet-1')
print('4----------------------')
f1.pay_tips(20)
print('5----------------------')
print(f1.show_orders())
f2 = Foodie('Bilbo')
print('6----------------------')
f2.order('Prawn Tempura-6','Saute Veg-1')
print('7----------------------')
f2.pay_tips()
print('8----------------------')
print(f2.show_orders())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\code code code\ass-4.ipynb Cell 2 line 1
#       <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a> menu = {'Chicken Lollipop':15,'Beef Nugget':20,'Americano':180,'Red Velvet':150,'Prawn Tempura':80,'Saute Veg':200}
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#W1sZmlsZQ%3D%3D?line=10'>11</a> f1 = Foodie('Frodo')
# ---> <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#W1sZmlsZQ%3D%3D?line=11'>12</a> print(f1.show_orders())
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#W1sZmlsZQ%3D%3D?line=12'>13</a> print('1----------------------')
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#W1sZmlsZQ%3D%3D?line=13'>14</a> f1.order('Chicken Lollipop-3','Beef Nugget-6','Americano-1')
#
# ...

# %%
# chat1
class Student:
    def __init__(self, name, cgpa, credit=0, department="CSE"):
        self.name = name
        self.cgpa = cgpa
        self.credit = credit
        self.department = department
        self.scholarship_status = ""

    def checkScholarshipEligibility(self):
        if self.cgpa >= 3.7:
            self.scholarship_status = "Merit-based scholarship"
        elif self.cgpa >= 3.5 and self.credit > 10:
            self.scholarship_status = "Scholarship"
        elif self.cgpa >= 3.5:
            self.scholarship_status = "Need-based scholarship"
        else:
            self.scholarship_status = "No scholarship"

        if self.scholarship_status == "No scholarship":
            print(f"{self.name} is not eligible for scholarship.")
        else:
            print(f"{self.name} is eligible for {self.scholarship_status}.")

    def showDetails(self):
        print(f"Name: {self.name}")
        print(f"Department: {self.department}")
        print(f"CGPA: {self.cgpa}")
        print(f"Number of Credits: {self.credit}")
        print(f"Scholarship Status: {self.scholarship_status}")


# Driver code
print('--------------------------')
std1 = Student("Alif", 3.99, 12)
print('--------------------------')
std1.checkScholarshipEligibility()
print('--------------------------')
std1.showDetails()
print('--------------------------')
std2 = Student("Mim", 3.4)
std3 = Student("Henry", 3.5, 15, "BBA")
print('--------------------------')
std2.checkScholarshipEligibility()
print('--------------------------')
std3.checkScholarshipEligibility()
print('--------------------------')
std2.showDetails()
print('--------------------------')
std3.showDetails()
print('--------------------------')
std4 = Student("Bob", 4.0, 6, "CSE")
print('--------------------------')
std4.checkScholarshipEligibility()
print('--------------------------')
std4.showDetails()
# Out:
# --------------------------
# --------------------------
# Alif is eligible for Merit-based scholarship.
# --------------------------
# Name: Alif
# Department: CSE
# CGPA: 3.99
# Number of Credits: 12
# Scholarship Status: Merit-based scholarship
# --------------------------
# --------------------------
# Mim is not eligible for scholarship.
# --------------------------
# Henry is eligible for Scholarship.
# --------------------------
# Name: Mim
# Department: CSE
# CGPA: 3.4
# Number of Credits: 0
# Scholarship Status: No scholarship
# --------------------------
# Name: Henry
# Department: BBA
# CGPA: 3.5
# Number of Credits: 15
# Scholarship Status: Scholarship
# --------------------------
# --------------------------
# Bob is eligible for Merit-based scholarship.
# --------------------------
# Name: Bob
# Department: CSE
# CGPA: 4.0
# Number of Credits: 6
# Scholarship Status: Merit-based scholarship

# %%
# chat2
class Foodie:
    menu = {
        'Chicken Lollipop': 15,
        'Beef Nugget': 20,
        'Americano': 180,
        'Red Velvet': 150,
        'Prawn Tempura': 80,
        'Saute Veg': 200
    }

    def __init__(self, name):
        self.name = name
        self.cart = {}
        self.total_spent = 0
        self.waiter_tips = 0

    def order(self, *items):
        for item in items:
            food, quantity = item.split('-')
            food = food.strip()
            quantity = int(quantity)
            if food in self.menu:
                if food in self.cart:
                    self.cart[food] += quantity
                else:
                    self.cart[food] = quantity
                print(f"Ordered - {food}, quantity - {quantity}, price (per Unit) - {self.menu[food]}.")
                print(f"Total price - {self.menu[food] * quantity}")
                self.total_spent += self.menu[food] * quantity
            else:
                print(f"{food} is not in the menu.")

    def pay_tips(self, tips=0):
        if tips > 0:
            self.waiter_tips += tips
            print(f'Gives {tips}/- tips to the waiter.')
        else:
            print('No tips to the waiter.')

    def show_orders(self):
        item_count = len(self.cart)
        items = list(self.cart.keys())
        total_spent = self.total_spent + self.waiter_tips
        print(f'{self.name} has {item_count} item(s) in the cart.')
        print(f'Items: {items}')
        return(f'Total spent: {total_spent}.')

# Driver code
# menu = {
#     'Chicken Lollipop': 15,
#     'Beef Nugget': 20,
#     'Americano': 180,
#     'Red Velvet': 150,
#     'Prawn Tempura': 80,
#     'Saute Veg': 200
# }

f1 = Foodie('Frodo')
print(f1.show_orders())
print('1----------------------')
f1.order('Chicken Lollipop-3', 'Beef Nugget-6', 'Americano-1')
print('2----------------------')
print(f1.show_orders())
print('3----------------------')
f1.order('Red Velvet-1')
print('4----------------------')
f1.pay_tips(20)
print('5----------------------')
print(f1.show_orders())
f2 = Foodie('Bilbo')
print('6----------------------')
f2.order('Prawn Tempura-6', 'Saute Veg-1')
print('7----------------------')
f2.pay_tips()
print('8----------------------')
print(f2.show_orders())
# Out:
# Frodo has 0 item(s) in the cart.
# Items: []
# Total spent: 0.
# 1----------------------
# Ordered - Chicken Lollipop, quantity - 3, price (per Unit) - 15.
# Total price - 45
# Ordered - Beef Nugget, quantity - 6, price (per Unit) - 20.
# Total price - 120
# Ordered - Americano, quantity - 1, price (per Unit) - 180.
# Total price - 180
# 2----------------------
# Frodo has 3 item(s) in the cart.
# Items: ['Chicken Lollipop', 'Beef Nugget', 'Americano']
# Total spent: 345.
# 3----------------------
# Ordered - Red Velvet, quantity - 1, price (per Unit) - 150.
# Total price - 150
# 4----------------------
# Gives 20/- tips to the waiter.
# 5----------------------
# Frodo has 4 item(s) in the cart.
# Items: ['Chicken Lollipop', 'Beef Nugget', 'Americano', 'Red Velvet']
# Total spent: 515.
# 6----------------------
# Ordered - Prawn Tempura, quantity - 6, price (per Unit) - 80.
# Total price - 480
# Ordered - Saute Veg, quantity - 1, price (per Unit) - 200.
# Total price - 200
# ...

# %%
class Department:
    def __init__(self, name="ChE Department", sections=5):
        self.name = name
        self.sections = sections
        self.students = []

    def add_students(self, *students):
        if len(students) == self.sections:
            self.students = students
            print(f'The {self.name} has {self.sections} sections.')
        else:
            print(f'The {self.name} doesn\'t have {len(students)} sections.')

    def average_students_per_section(self):
        if len(self.students) == self.sections:
            return sum(self.students) / self.sections
        else:
            return 0

    def merge_Department(self, *departments):
        total_students = 0
        total_sections = 0

        for dept in departments:
            total_students += dept.average_students_per_section() * dept.sections
            total_sections += dept.sections

        total_students += self.average_students_per_section() * self.sections
        total_sections += self.sections

        self.sections = total_sections
        self.students = [total_students // total_sections] * total_sections

        merged_departments = [dept.name for dept in departments]
        merged_departments.append(self.name)

        print(', '.join(merged_departments) + f' is merged to {self.name}.')
        return f'Now the {self.name} has an average of {self.average_students_per_section():.1f} students in each section.'


# Driver code
d1 = Department()
print('1-----------------------------')
d2 = Department('MME Department')
print('2-----------------------------')
d3 = Department('NCE Department', 8)
print('3-----------------------------')
d1.add_students(12, 23, 12, 34, 21)
print('4-----------------------------')
d2.add_students(40, 30, 21)
print('5-----------------------------')
d3.add_students(12, 34, 41, 17, 30, 22, 32, 51)
print('6-----------------------------')
mega = Department('Engineering Department', 10)
print('7-----------------------------')
mega.add_students(21, 30, 40, 36, 10, 32, 27, 51, 45, 15)
print('8-----------------------------')
print(mega.merge_Department(d1, d2))
print('9-----------------------------')
print(mega.merge_Department(d3))
# Out:
# 1-----------------------------
# 2-----------------------------
# 3-----------------------------
# The ChE Department has 5 sections.
# 4-----------------------------
# The MME Department doesn't have 3 sections.
# 5-----------------------------
# The NCE Department has 8 sections.
# 6-----------------------------
# 7-----------------------------
# The Engineering Department has 10 sections.
# 8-----------------------------
# ChE Department, MME Department, Engineering Department is merged to Engineering Department.
# Now the Engineering Department has an average of 20.0 students in each section.
# 9-----------------------------
# NCE Department, Engineering Department is merged to Engineering Department.
# Now the Engineering Department has an average of 22.0 students in each section.

# %%
class Department:
    def __init__(self, name="ChE Department", sections=5):
        self.name = name
        self.sections = sections
        self.students = []

    def add_students(self, *students):
        if len(students) == self.sections:
            self.students = students
            print(f'The {self.name} has {self.sections} sections.')
        else:
            print(f'The {self.name} doesn\'t have {len(students)} sections.')

    def merge_Department(self, *departments):
        total_students = 0
        total_sections = self.sections

        for dept in departments:
            total_students += sum(dept.students)
            total_sections += dept.sections

        self.sections = total_sections
        self.students = [total_students // total_sections] * total_sections

        merged_departments = [dept.name for dept in departments]
        merged_departments.append(self.name)

        print(', '.join(merged_departments) + f' is merged to {self.name}.')
        return f'Now the {self.name} has an average of {total_students / total_sections:.1f} students in each section.'


# Driver code
d1 = Department()
print('1-----------------------------')
d2 = Department('MME Department')
print('2-----------------------------')
d3 = Department('NCE Department', 8)
print('3-----------------------------')
d1.add_students(12, 23, 12, 34, 21)
print('4-----------------------------')
d2.add_students(40, 30, 21)
print('5-----------------------------')
d3.add_students(12, 34, 41, 17, 30, 22, 32, 51)
print('6-----------------------------')
mega = Department('Engineering Department', 10)
print('7-----------------------------')
mega.add_students(21, 30, 40, 36, 10, 32, 27, 51, 45, 15)
print('8-----------------------------')
print(mega.merge_Department(d1, d2))
print('9-----------------------------')
print(mega.merge_Department(d3))
# Out:
# 1-----------------------------
# 2-----------------------------
# 3-----------------------------
# The ChE Department has 5 sections.
# 4-----------------------------
# The MME Department doesn't have 3 sections.
# 5-----------------------------
# The NCE Department has 8 sections.
# 6-----------------------------
# 7-----------------------------
# The Engineering Department has 10 sections.
# 8-----------------------------
# ChE Department, MME Department, Engineering Department is merged to Engineering Department.
# Now the Engineering Department has an average of 5.1 students in each section.
# 9-----------------------------
# NCE Department, Engineering Department is merged to Engineering Department.
# Now the Engineering Department has an average of 8.5 students in each section.

# %%
class Department:
    def __init__(self,dept='ChE Department',sec=5):
        self.dept=dept;self.sec=sec
        print(f'The {self.dept} has {self.sec} sections.')
    def add_students(self,*args):
        for i in args:
            
    def merge_Department(self,*department):
        pass
d1 = Department()
print('1-----------------------------')
d2 = Department('MME Department')
print('2-----------------------------')
d3 = Department('NCE Department', 8)
print('3-----------------------------')
d1.add_students(12, 23, 12, 34, 21)
print('4-----------------------------')
d2.add_students(40, 30, 21)
print('5-----------------------------')
d3.add_students(12, 34, 41, 17, 30, 22, 32, 51)
print('6-----------------------------')
mega = Department('Engineering Department', 10)
print('7-----------------------------')
mega.add_students(21,30,40,36,10,32,27,51,45,15)
print('8-----------------------------')
print(mega.merge_Department(d1, d2))
print('9-----------------------------')
print(mega.merge_Department(d3))

# %%
class Shopidify:
    user_count = 0
    transaction_count = 0

    def __init__(self, username="Guest"):
        self.username = username
        self.cart = {}
        self.purchase_history = {}
        self.user_id = Shopidify.user_count + 1
        Shopidify.user_count += 1

    def add_to_cart(self, *items):
        if not items:
            return

        for item in items:
            if isinstance(item, list):
                for i in range(0, len(item), 2):
                    product = item[i]
                    quantity = item[i + 1] if i + 1 < len(item) else 1
                    self.cart[product] = self.cart.get(product, 0) + quantity
            else:
                self.cart[item] = self.cart.get(item, 0) + 1

    def display_cart(self):
        if self.username == "Guest":
            print(f"Items in the cart for {self.username}:")
        else:
            print(f"Items in the cart for {self.username} ({self.user_id}):")

        for item, quantity in self.cart.items():
            print(f"- {item}: {quantity}x")

    def checkout(self):
        if not self.cart:
            return

        Shopidify.transaction_count += 1
        transaction = {}
        for item, quantity in self.cart.items():
            transaction[item] = quantity
        self.purchase_history[f"Transaction {Shopidify.transaction_count}"] = transaction
        self.cart = {}

    def display_history(self):
        print(f"Purchase history for {self.username} ({self.user_id}):")
        for transaction, items in self.purchase_history.items():
            print(f"{transaction}:")
            for item, quantity in items.items():
                print(f"- {item}: {quantity}x")


# Driver code
guest_account = Shopidify()
print("1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account = Shopidify("John")
print("2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan", 2)
guest_account.add_to_cart("Luffy Action Figure")
guest_account.display_cart()
print("3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.add_to_cart(["Chocolate Chip Cookies", 3, "Goku Action Figure", 2, "Dumbbells-5kg", 2])
john_account.display_cart()
print("4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan")
guest_account.display_cart()
print("5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.checkout()
print("6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.display_history()
print("7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.checkout()
print("8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.display_history()
print("9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
# Out:
# 1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for Guest:
# - Air Jordan: 1x
# - 2: 1x
# - Luffy Action Figure: 1x
# 3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for John (2):
# - Chocolate Chip Cookies: 3x
# - Goku Action Figure: 2x
# - Dumbbells-5kg: 2x
# 4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for Guest:
# - Air Jordan: 2x
# - 2: 1x
# - Luffy Action Figure: 1x
# 5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Purchase history for Guest (1):
# Transaction 1:
# - Air Jordan: 2x
# - 2: 1x
# - Luffy Action Figure: 1x
# 7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Purchase history for John (2):
# Transaction 2:
# - Chocolate Chip Cookies: 3x
# - Goku Action Figure: 2x
# - Dumbbells-5kg: 2x
# 9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %% [markdown]
# task5

# %%
class Shopidify:
    def __init__(self, username="Guest"):
        self.username = username
        self.cart = {}
        self.purchase_history = {}
        if username=='Guest':
            print(f'Welcome to Shopidify 1')
        else:
            print(f'Welcome {self.username} to Shopidify')

    def add_to_cart(self, *items):
        if not items:
            return

        for item in items:
            if isinstance(item, str):
                self._add_single_item(item)
            elif isinstance(item, list):
                self._add_multiple_items(item)

    def _add_single_item(self, item):
        self.cart[item] = self.cart.get(item, 0) + 1

    def _add_multiple_items(self, items):
        for i in range(0, len(items), 2):
            product = items[i]
            quantity = items[i + 1] if i + 1 < len(items) else 1
            self.cart[product] = self.cart.get(product, 0) + quantity

    def display_cart(self):
        print(f"Items in the cart for {self.username}:")
        for item, quantity in self.cart.items():
            print(f"- {item}: {quantity}x")

    def checkout(self):
        if not self.cart:
            return

        transaction = {}
        for item, quantity in self.cart.items():
            transaction[item] = quantity

        transaction_number = len(self.purchase_history) + 1
        self.purchase_history[f"Transaction {transaction_number}"] = transaction
        self.cart = {}

    def display_history(self):
        print(f"Purchase history for {self.username}:")
        for transaction, items in self.purchase_history.items():
            print(f"{transaction}:")
            for item, quantity in items.items():
                print(f"- {item}: {quantity}x")

# Test the Shopidify class
guest_account = Shopidify()
print("1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account = Shopidify("John")
print("2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan", 2)
guest_account.add_to_cart("Luffy Action Figure")
guest_account.display_cart()
print("3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.add_to_cart(["Chocolate Chip Cookies", 3, "Goku Action Figure", 2, "Dumbbells-5kg", 2])
john_account.display_cart()
print("4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan")
guest_account.display_cart()
print("5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.checkout()
print("6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.display_history()
print("7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.checkout()
print("8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.display_history()
print("9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
# Out:
# Welcome to Shopidify 1
# 1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Welcome John to Shopidify
# 2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for Guest:
# - Air Jordan: 1x
# - Luffy Action Figure: 1x
# 3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for John:
# - Chocolate Chip Cookies: 3x
# - Goku Action Figure: 2x
# - Dumbbells-5kg: 2x
# 4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for Guest:
# - Air Jordan: 2x
# - Luffy Action Figure: 1x
# 5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Purchase history for Guest:
# Transaction 1:
# - Air Jordan: 2x
# - Luffy Action Figure: 1x
# 7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Purchase history for John:
# Transaction 1:
# - Chocolate Chip Cookies: 3x
# - Goku Action Figure: 2x
# - Dumbbells-5kg: 2x
# 9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
#             /\
#            ///\
#           /////\
#          ///////\
#            !!!!
#            !!!!
#            !!!!

# %%
class Shopidify:
    def __init__(self,name=None):
        self.name=name
    def __init__(self,name):
        self.name=name,
    def add_to_cart(self,*stuffs):
        pass
    def display_cart(self):
        print(f'Items in the cart for {self.}')
# Test the Shopidify class
guest_account = Shopidify()
print("1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account = Shopidify("John")
print("2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan", 2)
guest_account.add_to_cart("Luffy Action Figure")
guest_account.display_cart()
print("3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.add_to_cart(["Chocolate Chip Cookies", 3,"Goku Action Figure",2,"Dumbbells-5kg",2])
john_account.display_cart()
print("4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan")
guest_account.display_cart()
print("5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.checkout()
print("6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.display_history()
print("7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.checkout()
print("8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.display_history()
print("9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
# Out:
#   Cell In[168], line 9
#     print(f'Items in the cart for {self.}')
#     ^
# SyntaxError: f-string: invalid syntax

# %%
# chat 6 /////**********/////
class Author:
    def __init__(self, name=""):
        self.name = name
        self.books = {}

    def addBook(self, title, genre):
        if self.name == "":
            print("A book cannot be added without an author name.")
        else:
            if genre not in self.books:
                self.books[genre] = []
            self.books[genre].append(title)

    def setName(self, name):
        self.name = name

    def printDetail(self):
        print("Number of Book(s):", sum(len(books) for books in self.books.values()))
        print("Author Name:", self.name)
        for genre, titles in self.books.items():
            print(f"{genre}: {', '.join(titles)}")

# Test the Author class
a1 = Author()
print("=================================")
a1.addBook("Ice", "Science Fiction")
print("=================================")
a1.setName("Anna Kavan")
a1.addBook("Ice", "Science Fiction")
a1.printDetail()
print("=================================")

a2 = Author("Humayun Ahmed")
a2.addBook("Onnobhubon", "Science Fiction")
a2.addBook("Megher Upor Bari", "Horror")
print("=================================")
a2.printDetail()

a2.addBook("Ireena", "Science Fiction")
print("=================================")
a2.printDetail()
print("=================================")
# Out:
# ...
# A book cannot be added without an author name.
# ...
# Number of Book(s): 1
# Author Name: Anna Kavan
# Science Fiction: Ice
# ...
# Number of Book(s): 2
# Author Name: Humayun Ahmed
# Science Fiction: Onnobhubon
# Horror: Megher Upor Bari
# ...
# Number of Book(s): 3
# Author Name: Humayun Ahmed
# Science Fiction: Onnobhubon, Ireena
# Horror: Megher Upor Bari
# ...

# %%
class Author:
    def __init__(self,name=None):
        self.author=name;self.books={}
    def addBook(self,book_name,book_catagory):
        if self.author:
            if book_catagory not in self.books:
                self.books[book_catagory]=[book_name]
            else:
                self.books[book_catagory].append(book_name)
        else:
            print('A book can not be added without author name')
    def setName(self,author):
        self.author=author
    def printDetail(self):
        books=0
        for i in self.books.values():
            for value in i:
                books+=1
        print(f'Number of Book(s): {books}')
        print(f'Author Name: {self.author}')
        for k,v in self.books.items():
            out=', '.join(v)
            print(f'{k}: {out}')
# Do not change the following lines of code. 
a1 = Author() 
print("=================================") 
a1.addBook("Ice", "Science Fiction") 
print("=================================") 
a1.setName("Anna Kavan") 
a1.addBook("Ice", "Science Fiction") 
a1.printDetail() 
print("=================================") 
a2 = Author("Humayun Ahmed") 
a2.addBook("Onnobhubon", "Science Fiction") 
a2.addBook("Megher Upor Bari", "Horror") 
print("=================================") 
a2.printDetail() 
a2.addBook("Ireena", "Science Fiction") 
print("=================================") 
a2.printDetail() 
print("=================================")
# Out:
# ...
# A book can not be added without author name
# ...
# Number of Book(s): 1
# Author Name: Anna Kavan
# Science Fiction: Ice
# ...
# Number of Book(s): 2
# Author Name: Humayun Ahmed
# Science Fiction: Onnobhubon
# Horror: Megher Upor Bari
# ...
# Number of Book(s): 3
# Author Name: Humayun Ahmed
# Science Fiction: Onnobhubon, Ireena
# Horror: Megher Upor Bari
# ...

# %%
class Author:
  def __init__(self, name="Default", *books):
    self.name = name
    self.books = list(books)

  def addBook(self, *books):
    self.books.extend(books)
  
  def setName(self, name):
    self.name = name
        
  
  def printDetails(self):
    print(f"Author Name: {self.name}")
    print("--------")
    print("List of Books:")
    
    for i in self.books:
      print(i)
# Do not change the following lines of code. a1 = Author() 
print("=================================") 
a1.addBook("Ice", "Science Fiction") 
print("=================================") 
a1.setName("Anna Kavan") 
a1.addBook("Ice", "Science Fiction") 
a1.printDetail() 
print("=================================") 
a2 = Author("Humayun Ahmed") 
a2.addBook("Onnobhubon", "Science Fiction") 
a2.addBook("Megher Upor Bari", "Horror") 
print("=================================") 
a2.printDetail() 
a2.addBook("Ireena", "Science Fiction") 
print("=================================") 
a2.printDetail() 
print("=================================")
# Out:
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\code code code\ass-4.ipynb Cell 14 line 2
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#X41sZmlsZQ%3D%3D?line=19'>20</a> # Do not change the following lines of code. a1 = Author()
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#X41sZmlsZQ%3D%3D?line=20'>21</a> print("=================================")
# ---> <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#X41sZmlsZQ%3D%3D?line=21'>22</a> a1.addBook("Ice", "Science Fiction")
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#X41sZmlsZQ%3D%3D?line=22'>23</a> print("=================================")
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#X41sZmlsZQ%3D%3D?line=23'>24</a> a1.setName("Anna Kavan")
#
# ...

# %%
# task3
class Department:
    def __init__(self,dept='ChE',sec=5):
        self.dept=dept;self.sec=sec
        print(f'The {dept} Department has {sec} sections.')
    def add_students(self,*students):
        sum=0
        for i in students:
            sum+=i
            if len(students)==self.sec:
                avg=sum/self.sec
                out=(f'The {self.dept} Department has an average of {avg} students in each section.')
            elif len(students)!=self.sec:
                out=(f"The {self.dept} Department doesn't have {len(students)} sections.")
        print(out)
    # def merge_Department(self,*departments):
    #     total_students=0
    #     total_sec=0
    #     merged_dept=[]
    #     for i in departments:
    #         total_students+=self.total+i.total
    #         total_sec+=i.sec
    #     mega_avg=total_students/total_sec
    #     merged_dept.append(i.dept+'is merged to Engineering Department.')
    #     print('\n'.join(merged_dept))
    #     return f'Now the {self.dept} has an average of {round(mega_avg,1)} students in each section.'
    def merge_Department(self, *departments):
        total_students = 0
        total_sections = self.sec

        for i in departments:
            total_students += sum(i.students)
            total_sections += i.sec

        self.sec = total_sections
        self.students = [total_students // total_sections] * total_sections

        merged_departments = [dept.name for dept in departments]
        merged_departments.append(self.name)

        print(', '.join(merged_departments) + f' is merged to {self.name}.')
        return f'Now the {self.name} has an average of {total_students / total_sections:.1f} students in each section.'
d1 = Department()
print('1-----------------------------')
d2 = Department('MME Department')
print('2-----------------------------')
d3 = Department('NCE Department', 8)
print('3-----------------------------')
d1.add_students(12, 23, 12, 34, 21)
print('4-----------------------------')
d2.add_students(40, 30, 21)
print('5-----------------------------')
d3.add_students(12, 34, 41, 17, 30, 22, 32, 51)
print('6-----------------------------')
mega = Department('Engineering Department', 10)
print('7-----------------------------')
mega.add_students(21,30,40,36,10,32,27,51,45,15)
print('8-----------------------------')
print(mega.merge_Department(d1, d2))
print('9-----------------------------')
print(mega.merge_Department(d3))
# Out:
# The ChE Department has 5 sections.
# 1-----------------------------
# The MME Department Department has 5 sections.
# 2-----------------------------
# The NCE Department Department has 8 sections.
# 3-----------------------------
# The ChE Department has an average of 20.4 students in each section.
# 4-----------------------------
# The MME Department Department doesn't have 3 sections.
# 5-----------------------------
# The NCE Department Department has an average of 29.875 students in each section.
# 6-----------------------------
# The Engineering Department Department has 10 sections.
# 7-----------------------------
# The Engineering Department Department has an average of 30.7 students in each section.
# 8-----------------------------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\code code code\ass-4.ipynb Cell 14 line 5
# ...

# %%
# task3
class Department:
    def __init__(self,dept='ChE Department',sec=5):
        self.dept=dept;self.sec=sec
        self.sum=0
        self.avg=0
        # self.student=Student
        print(f'The {dept} has {sec} sections.')
    def add_students(self,*students):
        self.sum=0
        self.avg=0
        for i in students:
            self.sum+=i
            if len(students)==self.sec:
                self.avg=self.sum/self.sec
                out=(f'The {self.dept} has an average of {round(self.avg,2)} students in each section.')
            elif len(students)!=self.sec:
                out=(f"The {self.dept} doesn't have {len(students)} sections.")
        self.ss=(self.avg*self.sec)
        print(out)
    def merge_Department(self, *departments):
        self.T=self.ss
        self.depart=list(departments)
        for i in departments:
            self.T+=(i.avg*i.sec)
        self.ss=self.T
        self.average=round(self.ss/self.sec,2)
        a=''
        for i in self.depart:
            a+=f'{i.dept} is merged to Engineering Department.\n'
            out=f'Now the Engineering Department has an average of {self.average} students in each section.'
        return a+out
    
d1 = Department()
print('1-----------------------------')
d2 = Department('MME Department')
print('2-----------------------------')
d3 = Department('NCE Department', 8)
print('3-----------------------------')
d1.add_students(12, 23, 12, 34, 21)
print('4-----------------------------')
d2.add_students(40, 30, 21)
print('5-----------------------------')
d3.add_students(12, 34, 41, 17, 30, 22, 32, 51)
print('6-----------------------------')
mega = Department('Engineering Department', 10)
print('7-----------------------------')
mega.add_students(21,30,40,36,10,32,27,51,45,15)
print('8-----------------------------')
print(mega.merge_Department(d1, d2))
print('9-----------------------------')
print(mega.merge_Department(d3))
# Out:
# The ChE Department has 5 sections.
# 1-----------------------------
# The MME Department has 5 sections.
# 2-----------------------------
# The NCE Department has 8 sections.
# 3-----------------------------
# The ChE Department has an average of 20.4 students in each section.
# 4-----------------------------
# The MME Department doesn't have 3 sections.
# 5-----------------------------
# The NCE Department has an average of 29.88 students in each section.
# 6-----------------------------
# The Engineering Department has 10 sections.
# 7-----------------------------
# The Engineering Department has an average of 30.7 students in each section.
# 8-----------------------------
# ChE Department is merged to Engineering Department.
# MME Department is merged to Engineering Department.
# Now the Engineering Department has an average of 40.9 students in each section.
# 9-----------------------------
# NCE Department is merged to Engineering Department.
# ...

# %%
# task4
class Shopidify:
    def __init__(self,name='Guest'):
        self.name=name
        self.dict1={}
        self.dict2={}
    def add_to_cart(self,item,amount=1):
        if type(item)==list:
            goods=''
            for y in item:
                print(y)
            # print(goods)
            # for k in range(0,len(item),2):
            #     print(k)
            # print()
        for i in item:
            self.dict1[item]=amount   
        print(self.dict1)    
    def display_cart(self):
        # print(f'Items in the cart for {self.}')
        pass
# Test the Shopidify class
guest_account = Shopidify()
print("1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account = Shopidify("John")
print("2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan", 2)
guest_account.add_to_cart("Luffy Action Figure")
guest_account.display_cart()
print("3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.add_to_cart(["Chocolate Chip Cookies", 3,"Goku Action Figure",2,"Dumbbells-5kg",2])
john_account.display_cart()
print("4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan")
guest_account.display_cart()
print("5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.checkout()
print("6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.display_history()
print("7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.checkout()
print("8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.display_history()
print("9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
# Out:
# 1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# {'Air Jordan': 2}
# {'Air Jordan': 2, 'Luffy Action Figure': 1}
# 3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Chocolate Chip Cookies
# 3
# Goku Action Figure
# 2
# Dumbbells-5kg
# 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\code code code\ass-4.ipynb Cell 16 line 3
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#X30sZmlsZQ%3D%3D?line=28'>29</a> guest_account.display_cart()
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#X30sZmlsZQ%3D%3D?line=29'>30</a> print("3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
# ---> <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#X30sZmlsZQ%3D%3D?line=30'>31</a> john_account.add_to_cart(["Chocolate Chip Cookies", 3,"Goku Action Figure",2,"Dumbbells-5kg",2])
# ...

# %%
class MidA:
    def __init__(self):
        self.x = 3
        self.y = 7
        self.sum = 0
    def methodA(self, x):
        self.y = x + self.sum + self.x
        self.sum = x + self.y
        z = MidA()
        z.sum = self.sum + self.y
        self.methodB(z)
        print(self.x, self.y, self.sum)
    def methodB(self, a):
        y = 3
        a.x = self.x + self.sum;
        self.sum = a.x + a.y + y
        print(a.x, a.y, a.sum)
a = MidA()
a.methodA(5)
# Out:
# 16 7 21
# 3 8 26

# %%
class MidA:
    def __init__(self):
        self.y,self.z,self.sum = 2,3,-1
    def m1(self, mg2, mg1=2):
        x = 0
        self.y = self.y + mg2[0]
        x += 33 + mg1
        self.sum += x + self.y
        mg2[0] = self.y + mg1
        mg1 = mg1 + x + 2
        print(x, self.y, self.sum)
    def m2(self, y=3):
        mid = [0]
        mid[0] = 7
        self.m1(mid, mid[0])
        z = y + mid[0]
        y = self.y + mid[0]
        self.sum = z + y + mid[0]
        print(z, y, self.sum)
a = MidA()
a.m1([6])
a.m2()
# Out:
# 35 8 42
# 40 15 97
# 25 37 84

# %%
# task6
class Lab4:
    def __init__(self):
        self.x = 3
        self.y = 2
        self.sum = 5
    def methodA(self, x):
        self.y = self.sum + self.x - x
        self.sum = x - self.y
        d = Lab4()
        d.sum = self.sum + self.methodB(d)
        print(self.x, self.y, self.sum)
        return d
    def methodB(self, t, z = 4):
        y = 2
        t.x = self.x + self.sum
        y = y + t.x - t.y
        self.sum = t.x + t.y + y - z
        if z == 4:
            return y
        print(t.x, t.y, self.sum)
        p = t.methodA(y)
        print(t.x, self.y, p.sum)
obj = Lab4()
obj2 = obj.methodA(4)
obj.methodB(obj2, 10)
# Out:
# 3 4 4
# 7 2 6
# 7 3 20
# 7 4 15

# %%
# task7
class Test4:
    def __init__(self):
        self.sum, self.y = 0, 0
    def methodA(self):
        x, y = 0, 0
        msg = [0]
        msg[0] = 5
        y = y + self.methodB(msg[0])
        x = y + self.methodB(msg, msg[0])
        self.sum = x + y + msg[0]
        print(x, y, self.sum)
    def methodB(self, *args):
        if len(args) == 1:
            mg1 = args[0]
            x, y = 0, 0
            y = y + mg1
            x = x + 33 + mg1
            self.sum = self.sum + x + y
            self.y = mg1 + x + 2
            print(x, y, self.sum)
            return y
        else:
            mg2, mg1 = args
            x = 0
            self.y = self.y + mg2[0]
            x = x + 33 + mg1
            self.sum = self.sum + x + self.y
            mg2[0] = self.y + mg1
            mg1 = mg1 + x + 2
            print(x, self.y, self.sum)
            return self.sum
t3 = Test4()
t3.methodA()
t3.methodA()
t3.methodA()
t3.methodA()
# Out:
# 38 5 43
# 38 50 131
# 136 5 196
# 38 5 239
# 38 50 327
# 332 5 392
# 38 5 435
# 38 50 523
# 528 5 588
# 38 5 631
# 38 50 719
# 724 5 784

# %%
class Shopidify:
    def __init__(self,name=None):
        self.name=name
        print(f'Welcome {self.name} to Shopidify')
    def add_to_cart(self,item,qty=1):
        self.dct={};self.item=item;self.qty=qty
        if self.name==None:
            self.dct[self.item]=self.qty
        else:
            # print(item)
            if type(item)==list:
                for k,l in item.split(','):
                    self.dct[k]=l
            
    def display_cart(self):
        if self.name==None:
            print('Items in the cart for Guest:')
        else:
            print(f'Items in the cart for {self.name}:')
        for i,j in self.dct.items():
            print(f'- {i}n: {j}x')
    def checkout(self):
        if self.name==None:
            print('Checkout completed for Guest')
        else:
            print(f'Checkout completed for {self.name}')
    def display_history(self):
        if self.name==None:
            print(f'Purchase history for Guest:\nTransaction 1:')
        else:
            print(f'Purchase history for {self.name}\nTransaction 1:')
# Test the Shopidify class
guest_account = Shopidify()
print("1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account = Shopidify("John")
print("2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan", 2)
guest_account.add_to_cart("Luffy Action Figure")
guest_account.display_cart()
print("3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.add_to_cart(["Chocolate Chip Cookies", 3,"Goku Action Figure",2,"Dumbbells-5kg",2])
john_account.display_cart()
print("4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan")
guest_account.display_cart()
print("5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.checkout()
print("6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.display_history()
print("7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.checkout()
print("8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.display_history()
print("9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
# Out:
# Welcome None to Shopidify
# 1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Welcome John to Shopidify
# 2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for Guest:
# - Luffy Action Figuren: 1x
# 3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\code code code\ass-4.ipynb Cell 23 line 4
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#X32sZmlsZQ%3D%3D?line=38'>39</a> guest_account.display_cart()
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#X32sZmlsZQ%3D%3D?line=39'>40</a> print("3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
# ---> <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#X32sZmlsZQ%3D%3D?line=40'>41</a> john_account.add_to_cart(["Chocolate Chip Cookies", 3,"Goku Action Figure",2,"Dumbbells-5kg",2])
# ...

# %%
class Shopidify:
    def __init__(self, name=None):
        self.name = name
        self.cart = {}  # Initialize an empty cart as a dictionary
        print(f'Welcome {self.name if self.name else "to Shopidify"}')

    def add_to_cart(self, item, qty=1):
        if item in self.cart:
            self.cart[item] += qty
        else:
            self.cart[item] = qty

    def display_cart(self):
        if self.name:
            print(f'Items in the cart for {self.name}:')
        else:
            print('Items in the cart for Guest:')
        for item, qty in self.cart.items():
            print(f'- {item}: {qty}x')

    def checkout(self):
        if self.name:
            print(f'Checkout completed for {self.name}')
        else:
            print('Checkout completed for Guest')
        self.display_history()

    def display_history(self):
        if self.name:
            print(f'Purchase history for {self.name}:')
        else:
            print('Purchase history for Guest:')
        transaction_number = 1
        for transaction in self.purchase_history:
            print(f'Transaction {transaction_number}:')
            for item, qty in transaction.items():
                print(f'- {item}: {qty}x')
            transaction_number += 1

    # def save_purchase_history(self):
    #     if not hasattr(self, 'purchase_history'):
        #     self.purchase_history = []
        # self.purchase_history.append(self.cart.copy())
    #     self.cart = {}  # Clear the cart after saving the purchase

# Test the Shopidify class
guest_account = Shopidify()
print("1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account = Shopidify("John")
print("2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan", 2)
guest_account.add_to_cart("Luffy Action Figure")
guest_account.display_cart()
print("3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.add_to_cart("Chocolate Chip Cookies", 3)
john_account.add_to_cart("Goku Action Figure", 2)
john_account.add_to_cart("Dumbbells-5kg", 2)
john_account.display_cart()
print("4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan")
guest_account.display_cart()
print("5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.checkout()
print("6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.display_history()
print("7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.checkout()
print("8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.display_history()
print("9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
# Out:
# Welcome to Shopidify
# 1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Welcome John
# 2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for Guest:
# - Air Jordan: 2x
# - Luffy Action Figure: 1x
# 3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for John:
# - Chocolate Chip Cookies: 3x
# - Goku Action Figure: 2x
# - Dumbbells-5kg: 2x
# 4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for Guest:
# - Air Jordan: 3x
# - Luffy Action Figure: 1x
# 5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Checkout completed for Guest
# Purchase history for Guest:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\code code code\ass-4.ipynb Cell 22 line 6
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#X33sZmlsZQ%3D%3D?line=60'>61</a> guest_account.display_cart()
# ...

# %%
class Shopidify:
    def __init__(self, name=None):
        self.name = name
        self.cart = {}  # Initialize an empty cart as a dictionary
        self.purchase_history = []  # Initialize an empty purchase history as a list
        self.transaction_number = 0  # Initialize a transaction number
        print(f'Welcome {self.name if self.name else "to Shopidify"}')

    def add_to_cart(self, item, qty=1):
        if item in self.cart:
            self.cart[item] += qty
        else:
            self.cart[item] = qty

    def display_cart(self):
        if self.name:
            print(f'Items in the cart for {self.name}:')
        else:
            print('Items in the cart for Guest:')
        for item, qty in self.cart.items():
            print(f'- {item}: {qty}x')

    def checkout(self):
        if self.name:
            print(f'Checkout completed for {self.name}')
        else:
            print('Checkout completed for Guest')
        self.transaction_number += 1
        self.purchase_history.append(self.cart.copy())
        self.display_history()

    def display_history(self):
        if self.name:
            print(f'Purchase history for {self.name}:')
        else:
            print('Purchase history for Guest:')
        for i, transaction in enumerate(self.purchase_history, start=1):
            print(f'Transaction {i}:')
            for item, qty in transaction.items():
                print(f'- {item}: {qty}x')

# Test the Shopidify class
guest_account = Shopidify()
print("1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account = Shopidify("John")
print("2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan", 2)
guest_account.add_to_cart("Luffy Action Figure")
guest_account.display_cart()
print("3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.add_to_cart(["Chocolate Chip Cookies", 3,"Goku Action Figure",2,"Dumbbells-5kg",2])
john_account.display_cart()
print("4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan")
guest_account.display_cart()
print("5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.checkout()
print("6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.display_history()
print("7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.checkout()
print("8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.display_history()
print("9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
# Out:
# Welcome to Shopidify
# 1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Welcome John
# 2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for Guest:
# - Air Jordan: 2x
# - Luffy Action Figure: 1x
# 3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\code code code\ass-4.ipynb Cell 23 line 5
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#X34sZmlsZQ%3D%3D?line=48'>49</a> guest_account.display_cart()
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#X34sZmlsZQ%3D%3D?line=49'>50</a> print("3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
# ---> <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#X34sZmlsZQ%3D%3D?line=50'>51</a> john_account.add_to_cart(["Chocolate Chip Cookies", 3,"Goku Action Figure",2,"Dumbbells-5kg",2])
# ...

# %%
class Shopidify:
    def __init__(self, name=None):
        self.name = name
        self.cart = {}
        self.purchase_history = []
        if self.name is None:
            print('Welcome Guest to Shopidify')
        else:
            print(f'Welcome {self.name} to Shopidify')

    def add_to_cart(self, items, qty=1):
        if isinstance(items, list):
            for i in range(0, len(items), 2):
                item = items[i]
                item_qty = items[i + 1] if i + 1 < len(items) else qty
                if item in self.cart:
                    self.cart[item] += item_qty
                else:
                    self.cart[item] = item_qty
        else:
            if items in self.cart:
                self.cart[items] += qty
            else:
                self.cart[items] = qty

    def display_cart(self):
        if self.name is None:
            print('Items in the cart for Guest:')
        else:
            print(f'Items in the cart for {self.name}:')
        for item, qty in self.cart.items():
            print(f'- {item}: {qty}x')

    def checkout(self):
        if self.name is None:
            print('Checkout completed for Guest')
        else:
            print(f'Checkout completed for {self.name}')
        self.purchase_history.append(self.cart)
        self.cart = {}

    def display_history(self):
        if self.name is None:
            print('Purchase history for Guest:\nTransaction 1:')
        else:
            print(f'Purchase history for {self.name}:\nTransaction 1:')

        transaction_number = 1
        for purchase in self.purchase_history:
            for item, qty in purchase.items():
                print(f'- {item}: {qty}x')
            transaction_number += 1
            


# Test the Shopidify class with the same driver code
guest_account = Shopidify()
print("1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account = Shopidify("John")
print("2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan", 2)
guest_account.add_to_cart("Luffy Action Figure")
guest_account.display_cart()
print("3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.add_to_cart(["Chocolate Chip Cookies", 3, "Goku Action Figure", 2, "Dumbbells-5kg", 2])
john_account.display_cart()
print("4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan")
guest_account.display_cart()
print("5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.checkout()
print("6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.display_history()
print("7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.checkout()
print("8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.display_history()
print("9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
# Out:
# Welcome Guest to Shopidify
# 1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Welcome John to Shopidify
# 2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for Guest:
# - Air Jordan: 2x
# - Luffy Action Figure: 1x
# 3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for John:
# - Chocolate Chip Cookies: 3x
# - Goku Action Figure: 2x
# - Dumbbells-5kg: 2x
# 4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for Guest:
# - Air Jordan: 3x
# - Luffy Action Figure: 1x
# 5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Checkout completed for Guest
# 6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Purchase history for Guest:
# Transaction 1:
# - Air Jordan: 3x
# - Luffy Action Figure: 1x
# 7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Checkout completed for John
# 8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Purchase history for John:
# Transaction 1:
# - Chocolate Chip Cookies: 3x
# - Goku Action Figure: 2x
# - Dumbbells-5kg: 2x
# 9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
class ABC:
    def __init__(self):
        self.x = 3
        self.y = 7
        self.sum = 0
    def methodA(self, x):
        self.y = x + self.sum + self.x
        self.sum = x + self.y
        z = ABC()
        z.sum = self.sum + self.y
        self.methodB(z)
        print(self.x, self.y, self.sum)
    def methodB(self, a):
        y = 3
        a.x = self.x + self.sum
        self.sum = a.x + a.y + y
        print(a.x, a.y, a.sum)
a = ABC()
a.methodA(5)
# Out:
# 16 7 21
# 3 8 26

# %%
# Write your code here
class Hospital:
    def __init__(self,name):
        self.name=name
        self.lst1=[]
        self.lst2=[]
        self.doc={};self.pat={}
class Doctor:
    def __init__(self,id,prof,dname,dtype):
        self.id=id;self.dname=dname;self.dtype=dtype;self.prof=prof
    def addDoctor(self,doc):
        self.doc[doc.id]=[doc.name,doc.dtype]
        print(self.doc)
class Patient:
    def __init__(self,id,prof,pname,age,pno):
        self.id=id;self.prof=prof;self.pname=pname;self.age=age;self.pno=pno
    def addPatient(self,pat):
        self.lst2.append(pat)
        print(self.lst2)

# Do not change the following lines of code.
h = Hospital("Evercare")
d1 = Doctor("1d","Doctor", "Samar Kumar", "Neurologist")
h.addDoctor(d1)
print("=================================")
print(h.getDoctorByID("1d"))
print("=================================")
p1 = Patient("1p","Patient", "Kashem Ahmed", 35, 12345)
h.addPatient(p1)
print("=================================")
print(h.getPatientByID("1p"))
print("=================================")
p2 = Patient ("2p","Patient", "Tanina Haque", 26, 33456)
h.addPatient(p2)
print("=================================")
print(h.getPatientByID("2p"))
print("=================================")
h.allDoctors()
h.allPatients()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\code code code\ass-4.ipynb Cell 28 line 2
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#X36sZmlsZQ%3D%3D?line=21'>22</a> h = Hospital("Evercare")
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#X36sZmlsZQ%3D%3D?line=22'>23</a> d1 = Doctor("1d","Doctor", "Samar Kumar", "Neurologist")
# ---> <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#X36sZmlsZQ%3D%3D?line=23'>24</a> h.addDoctor(d1)
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#X36sZmlsZQ%3D%3D?line=24'>25</a> print("=================================")
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-4.ipynb#X36sZmlsZQ%3D%3D?line=25'>26</a> print(h.getDoctorByID("1d"))
#
# AttributeError: 'Hospital' object has no attribute 'addDoctor'

# %%
class ParcelKoro:
    def __init__(self,name=None,product_weight=0):
        self.name=name;self.total=0;self.charge=0;self.product_weight=product_weight
        if self.name==None:
            self.name='No Name set'
        else:
            self.name=name
    def calculateFee(self,location=None):
        if location==None:
            self.charge=50
        else:
            self.charge=100
        self.total=(self.product_weight*20)+self.charge
        if self.product_weight==0:
            self.total=0
    # def product_weight(self,wei=):
    #     if self.weight==0:
    #         self.total=0
    def printDetails(self):
        print(f'Customer Name: {self.name}\nProduct Weight: {self.product_weight}\nTotal fee: {self.total}')
# Write your code here.
print("**********************")
p1 = ParcelKoro()
p1.calculateFee()
p1.printDetails()
print("**********************")
p2 = ParcelKoro('Bob The Builder')
p2.calculateFee()
p2.printDetails()
print("----------------------------")
p2.product_weight = 15
p2.calculateFee()
p2.printDetails()
print("**********************")
p3 = ParcelKoro('Dora The Explorer', 10)
p3.calculateFee('Dhanmondi')
p3.printDetails()
# Out:
# **********************
# Customer Name: No Name set
# Product Weight: 0
# Total fee: 0
# **********************
# Customer Name: Bob The Builder
# Product Weight: 0
# Total fee: 0
# ----------------------------
# Customer Name: Bob The Builder
# Product Weight: 15
# Total fee: 350
# **********************
# Customer Name: Dora The Explorer
# Product Weight: 10
# Total fee: 300

# %%
class Teacher:
    def __init__(self,name,dept):
        self.name=name;self.dept=dept
        self.lst=[]
    def addCourse(self,course):
        self.lst.append(course.cname)
    def printDetail(self):
        print('====================================')
        print(f'Name: {self.name}\nDepartment: {self.dept}\nList of courses')
        print('====================================')
        out='\n'.join(self.lst)
        print(out)
        print('====================================')

class Course:
    def __init__(self,cname):
        self.cname=cname
# Write your code here for subtasks 1-4
t1 = Teacher("Saad Abdullah", "CSE")
t2 = Teacher("Mumit Khan", "CSE")
t3 = Teacher("Sadia Kazi", "CSE") 
c1 = Course("CSE 110 Programming Language I") 
c2 = Course("CSE 111 Programming Language-II") 
c3 = Course("CSE 220 Data Structures") 
c4 = Course("CSE 221 Algorithms") 
c5 = Course("CCSE 230 Discrete Mathematics") 
c6 = Course("CSE 310 Object Oriented Programming") 
c7 = Course("CSE 320 Data Communications") 
c8 = Course("CSE 340 Computer Architecture")
t1.addCourse(c1)
t1.addCourse(c2)
t2.addCourse(c3)
t2.addCourse(c4)
t2.addCourse(c5)
t3.addCourse(c6)
t3.addCourse(c7)
t3.addCourse(c8)
t1.printDetail()
t2.printDetail()
t3.printDetail()
# Out:
# ...
# Name: Saad Abdullah
# Department: CSE
# List of courses
# ...
# CSE 110 Programming Language I
# CSE 111 Programming Language-II
# ...
# Name: Mumit Khan
# Department: CSE
# List of courses
# ...
# CSE 220 Data Structures
# CSE 221 Algorithms
# CCSE 230 Discrete Mathematics
# ...
# Name: Sadia Kazi
# Department: CSE
# List of courses
# ...
# CSE 310 Object Oriented Programming
# CSE 320 Data Communications
# CSE 340 Computer Architecture
# ...

# %%
# Write your code here
class TaxiLagbe:
    def __init__(self,tnum,area):
        self.tnum=tnum;self.area=area
        self.pas=0;self.passenger_lst=[]
        self.total=0
    def addPassenger(self,*args):
        for i in args:
            if self.pas<4:
                pname,fare=i.split('_')
                self.passenger_lst.append(pname)
                # print(self.passenger_lst)
                self.out=(', ').join(self.passenger_lst)
                self.total+=int(fare)
                print(f'Dear {pname}! Welcome to TaxiLagbe.')
                self.pas+=1
            else:
                print('Taxi Full! No more passengers can be added.')
    def printDetails(self):
        print(f'Trip info for Taxi number: {self.tnum}\nThis taxi can only cover the {self.area} area.')
        print(f'Total passengers: {len(self.passenger_lst)}\nPassenger lists:')
        print(f'{self.out}\nTotal collected fare: {self.total}')

taxi1 = TaxiLagbe('1010-01', 'Dhaka')
print('-------------------------------')
taxi1.addPassenger('Walker_100', 'Wood_200','Matt_100')
taxi1.addPassenger('Wilson_105')
print('-------------------------------')
taxi1.printDetails()
print('-------------------------------')
taxi1.addPassenger('Karen_200')
print('-------------------------------')
taxi1.printDetails()
print('-------------------------------')
taxi2 = TaxiLagbe('1010-02', 'Khulna')
taxi2.addPassenger('Ronald_115', 'Parker_215')
print('-------------------------------')
taxi2.printDetails()
# Out:
# -------------------------------
# Dear Walker! Welcome to TaxiLagbe.
# Dear Wood! Welcome to TaxiLagbe.
# Dear Matt! Welcome to TaxiLagbe.
# Dear Wilson! Welcome to TaxiLagbe.
# -------------------------------
# Trip info for Taxi number: 1010-01
# This taxi can only cover the Dhaka area.
# Total passengers: 4
# Passenger lists:
# Walker, Wood, Matt, Wilson
# Total collected fare: 505
# -------------------------------
# Taxi Full! No more passengers can be added.
# -------------------------------
# Trip info for Taxi number: 1010-01
# This taxi can only cover the Dhaka area.
# Total passengers: 4
# Passenger lists:
# Walker, Wood, Matt, Wilson
# Total collected fare: 505
# -------------------------------
# Dear Ronald! Welcome to TaxiLagbe.
# Dear Parker! Welcome to TaxiLagbe.
# -------------------------------
# Trip info for Taxi number: 1010-02
# This taxi can only cover the Khulna area.
# Total passengers: 2
# Passenger lists:
# Ronald, Parker
# Total collected fare: 330

# %%
class StudentDatabase:
    def __init__(self,name,id):
        self.name=name;self.id=id;self.grades={}
        self.cg=0
    def calculateGPA(self,lst,sem):
        course_lst=[];total_cg=0;dict1={}
        for i in lst:
            sub,cg=i.split(':')
            course_lst.append(sub)
            total_cg+=float(cg)
            self.cg=total_cg
        avg=total_cg/len(course_lst)
        dict1[tuple(course_lst)]=round(avg,2)
        dict1[tuple(course_lst)]=round(avg,2)
        # print(dict1)
        self.grades[sem]=dict1
        # print(self.grades)
    def printDetails(self):
        print(f'Name: {self.name}\nID: {self.id}')
        for i,j in self.grades.items():
            print(f'Courses taken in {i}')
            for k,v in j.items():
                out='\n'.join(k)
                print(out)
            print(f'GPA: {v}')
# Write your code here
s1 = StudentDatabase('Pietro', '10101222')
s1.calculateGPA(['CSE230: 4.0', 'CSE220: 4.0', 'MAT110: 4.0'], 'Summer2020')
s1.calculateGPA(['CSE250: 3.7', 'CSE330: 4.0'], 'Summer2021')
print(f'Grades for {s1.name}\n{s1.grades}')
print('---------------------------------')
s1.printDetails()
s2 = StudentDatabase('Wanda', '10103332')
s2.calculateGPA(['CSE111: 3.7', 'CSE260: 3.7', 'ENG101: 4.0'], 'Summer2022')
print('---------------------------------')
print(f'Grades for {s2.name}\n{s2.grades}')
print('---------------------------------')
s2.printDetails()
# Out:
# Grades for Pietro
# {'Summer2020': {('CSE230', 'CSE220', 'MAT110'): 4.0}, 'Summer2021': {('CSE250', 'CSE330'): 3.85}}
# ---------------------------------
# Name: Pietro
# ID: 10101222
# Courses taken in Summer2020
# CSE230
# CSE220
# MAT110
# GPA: 4.0
# Courses taken in Summer2021
# CSE250
# CSE330
# GPA: 3.85
# ---------------------------------
# Grades for Wanda
# {'Summer2022': {('CSE111', 'CSE260', 'ENG101'): 3.8}}
# ---------------------------------
# Name: Wanda
# ID: 10103332
# Courses taken in Summer2022
# CSE111
# CSE260
# ENG101
# GPA: 3.8

# %%
class Store:
    def __init__(self,balance):
        self.balance=balance
        self.dict1={};self.total_items=0
        self.inventory={}
        print('New branch created!')
    def add_item(self,item_lst):
        item_name,stock,buying_price,selling_price=item_lst
        if item_name in self.inventory:
            self.inventory[item_name][stock]+=stock
        else:
            self.inventory[item_name]={'stock':stock,'buying_price':buying_price,'selling_price':selling_price}
        self.balance-=stock*buying_price
        print(f'Item added: {self.item_name}')
        print(f'Current Balance: {self.balance}')
    def restock_item(self,)
print("==========================")
branch1 = Store(5000)
print(f"Current Balance: {branch1.balance}")
print(f"Total items: {branch1.total_items}")
branch1.viewAllItems()
branch1.viewAllItemDetails()
print("==========================")
print(f"Current Balance: {branch1.balance}")
branch1.add_item(["ChaCha Noodles", 10, 5, 8])
print(f"Current Balance: {branch1.balance}")
branch1.add_item(["Sparrow Shampoo", 5, 10, 20])
print(f"Current Balance: {branch1.balance}")
print("==========================")
branch1.viewAllItems()
print()
branch1.viewAllItemDetails()
print()
print("==========================")
print(f"Current Balance: {branch1.balance}\n")
branch1.sell_item("ChaCha Noodles", 15)
print(f"Current Balance: {branch1.balance}\n")
branch1.viewAllItemDetails()
print()
branch1.sell_item("ChaCha Noodles", 10)
print()
print(f"Current Balance: {branch1.balance}\n")
branch1.viewAllItemDetails()
print()
print("==========================")
print(f"Current Balance: {branch1.balance}\n")
branch1.restock_item("ChaCha Noodles", 5)
print()
branch1.viewAllItemDetails()
print()
print(f"Current Balance: {branch1.balance}\n")
print("==========================")
