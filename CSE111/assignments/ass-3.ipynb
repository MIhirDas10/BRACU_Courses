# %%
# task1
class CellPackage:
    def __init__(self,price,data,talk,sms,percent,val):
        self.price=int(price);self.data=(data);self.talk=int(talk);
        self.sms=int(sms);self.percent=(percent);self.val=int(val)
        print(self.data)
        print(f'Data = {self.data*1024}\nTalktime = {self.talk}\nSMS/MMS = {self.sms}')
        print(f'Validity = {self.val}\n--> Price = {self.price}')
        print(f'Buy now to get {10} tk cashback.')
# Driver Code
# Subtask 1: Write the CellPackage Class
pkg = CellPackage(150, '6 GB', 99, 20, '7%', 7)
print('============= Package 1 =============')
# Subtask 2: Check each attribute and print
pkg2 = CellPackage(700, '35 GB', 700, 0, '10%', 30)
print('============= Package 2 =============')
# Subtask 3: Check each attribute and print
pkg4 = CellPackage(120, '0 GB', 190, 0, '0%', 10)
print('============= Package 3 =============')
# Subtask 4: Check each attribute and print
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\code code code\ass-3.ipynb Cell 1 line 1
#       <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-3.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a>         print(f'Buy now to get {10} tk cashback.')
#       <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-3.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a> # Driver Code
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-3.ipynb#W0sZmlsZQ%3D%3D?line=9'>10</a> # Subtask 1: Write the CellPackage Class
# ---> <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-3.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a> pkg = CellPackage(150, '6 GB', 99, 20, '7%', 7)
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-3.ipynb#W0sZmlsZQ%3D%3D?line=11'>12</a> print('============= Package 1 =============')
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-3.ipynb#W0sZmlsZQ%3D%3D?line=12'>13</a> # Subtask 2: Check each attribute and print
#
# d:\code code code\ass-3.ipynb Cell 1 line 5
#       <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-3.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> self.price=int(price);self.data=(data);self.talk=int(talk);
#       <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-3.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> self.sms=int(sms);self.percent=(percent);self.val=int(val)
# ----> <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-3.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> print(int(self.data))
#       <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-3.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> print(f'Data = {self.data*1024}\nTalktime = {self.talk}\nSMS/MMS = {self.sms}')
#       <a href='vscode-notebook-cell:/d%3A/code%20code%20code/ass-3.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a> print(f'Validity = {self.val}\n--> Price = {self.price}')
#
# ValueError: invalid literal for int() with base 10: '6 GB'

# %%
# task1
class CellPackage:
    def __init__(self,price,data,talk,txt,cashback,validity):
        self.price=price;self.data=data;self.txt=txt;
        self.cashback=cashback;self.validity=validity
        info=data.split(' ')
        data=int(info[0])*1024
        cashback1=cashback.split('%')
        cash=int((price*(int(cashback1[0])/100)))
        if int(info[0])!=0:
            print(f'Data = {data} MB')
        if talk!=0:
            print(f'Talktime = {talk} minutes')
        if txt!=0:
            print(f'SMS/MMS = {txt}')
        print(f'Validity = {validity} days')
        print(f'--> price = {price} tk')
        if cash!=0:
            print(f'Buy now to get {cash} tk cashback')
# Driver Code
# Subtask 1: Write the CellPackage Class
pkg = CellPackage(150, '6 GB', 99, 20, '7%', 7)
print('============= Package 1 =============')
# Subtask 2: Check each attribute and print
pkg2 = CellPackage(700, '35 GB', 700, 0, '10%', 30)
print('============= Package 2 =============')
# Subtask 3: Check each attribute and print
pkg4 = CellPackage(120, '0 GB', 190, 0, '0%', 10)
print('============= Package 3 =============')
# Subtask 4: Check each attribute and print
# Out:
# Data = 6144 MB
# Talktime = 99 minutes
# SMS/MMS = 20
# Validity = 7 days
# --> price = 150 tk
# Buy now to get 10 tk cashback
# ============= Package 1 =============
# Data = 35840 MB
# Talktime = 700 minutes
# Validity = 30 days
# --> price = 700 tk
# Buy now to get 70 tk cashback
# ============= Package 2 =============
# Talktime = 190 minutes
# Validity = 10 days
# --> price = 120 tk
# ============= Package 3 =============

# %%
# task2
class box:
  def __init__(self, list1):
    self.height = list1[0]
    self.width = list1[1]
    self.breadth = list1[2]
    print(f"Creating a Box!")
  def boxDescription(self):
    print("Height:", self.height)
    print("Width:", self.width)
    print("Breadth:", self.breadth)
  def volume(self):
    return(f"Volume of the box is {self.height*self.width*self.breadth} cubic units.")
# Write your class code here
print("Box 1")
b1 = box([10,10,10])
print("=========================")
b1.boxDescription()
print(b1.volume())
print("-------------------------")
print("Box 2")
b2 = box((30,10,10))
print("=========================")
b2.boxDescription()
print(b2.volume())
b2.height = 300
print("Updating Box 2!")
print("Height:", b2.height)
print("Width:", b2.width)
print("Breadth:", b2.breadth)
volume = b2.height * b2.width * b2.breadth
print(f"Volume of the box is {volume} cubic units.")
print("-------------------------")
print("Box 3")
b3 = b2
b3.boxDescription()
print(b3.volume())
# Out:
# Box 1
# Creating a Box!
# =========================
# Height: 10
# Width: 10
# Breadth: 10
# Volume of the box is 1000 cubic units.
# -------------------------
# Box 2
# Creating a Box!
# =========================
# Height: 30
# Width: 10
# Breadth: 10
# Volume of the box is 3000 cubic units.
# Updating Box 2!
# Height: 300
# Width: 10
# Breadth: 10
# Volume of the box is 30000 cubic units.
# -------------------------
# Box 3
# Height: 300
# Width: 10
# Breadth: 10
# Volume of the box is 30000 cubic units.

# %%
one = (b3 == b2)
b3.width = 100
two = (b3 == b2)
print(one,two)
print(b2.width)
# Out:
# True True
# 100

# %%
# task3
class Vector3D:
    def __init__(self, x, y, z):
        self.x = x 
        self.y = y
        self.z = z
        print(f'Vector <{self.x}, {self.y}, {self.z}> created.')

# Write your driver code here
v1=Vector3D(2,-3,1)
v2=Vector3D(-1,4,0)
magnitude1 = (v1.x ** 2 + v1.y ** 2 + v1.z ** 2) ** 0.5
print(f'Magnitude of the first vector = {magnitude1}')
magnitude2 = (v2.x ** 2 + v2.y ** 2 + v2.z ** 2) ** 0.5
print(f'Magnitude of the second vector = {magnitude2}')
dot_product = v1.x * v2.x + v1.y * v2.y + v1.z * v2.z
print(f'Dot product of the two vector = {dot_product}')
cross_product = v1.y * v2.z - v1.z * v2.y,(v1.z * v2.x - v1.x * v2.z),(v1.x * v2.y - v1.y * v2.x)
# cross_product=cross_product
print(f'Cross product of the two vectors = <{cross_product}>')
# Out:
# Vector <2, -3, 1> created.
# Vector <-1, 4, 0> created.
# Magnitude of the first vector = 3.7416573867739413
# Magnitude of the second vector = 4.123105625617661
# Dot product of the two vector = -14
# Cross product of the two vectors = <(-4, -1, 5)>

# %%
class abcTech:
    def __init__(self,name,job,work):
        self.name=name;self.job=job;self.work=work
        self.lst=[]
        self.put=[]
        self.put1=None
        self.salary=None
        print(f'Welcome to abcTech, {self.name}')
    def addProgrammingSkills(self,skill):
        list_skill=[]
        list_skill.append(skill)
        print(list_skill)
        out=''
        # self.skill=skill
        for i in skill:
            out+='"'+i+'"'+', '
            self.out1=out[:-2]
            
    def calculateSalary(self,salary,hours):
        if hours>144:
            salary=salary+(abs(144-hours))*800
        # elif salary==144:
        else:
            salary=salary
        return salary
    def addFrameworks(self,*args):
        res=''
        for j in args:
            self.put+=j
        for k in self.put:
            res+='"'+k+'"'+', '
            self.put1=res[:-2]
    def printInfo(self):
        print(f'Name: {self.name}\nDesignation: {self.job}\nDepartment: {self.work}')
        print(f'Programming Skills: {self.out1}')
        print(f'Frameworks: {self.put1}')
print("-------------------------")
b1 =abcTech("Tamim Hasan", "Software Engineer", "Android Development")
print("-------------------------")
b1.addProgrammingSkills(["Java", "Python"])
b1.addProgrammingSkills(["Dart", "C++"])
b1.addFrameworks(["Express.js", "React"])
b1.printInfo()
print("-------------------------")
print(f"Your salary for this month is Tk. {b1.calculateSalary(45000, 156)}")
print("-------------------------")
print("-------------------------")
b2 =abcTech("Jahin Khandoker", "Senior Developer", "App Development")
print("-------------------------")
b2.addProgrammingSkills(["Java", "Dart", "Swift"])
b2.addFrameworks(["Flutter", "React Native"])
b2.addFrameworks(["Xamarin"])
b2.printInfo()
print("-------------------------")
print(f"Your salary for this month is Tk. {b2.calculateSalary(103000, 123)}")
print("-------------------------")
# Out:
# -------------------------
# Welcome to abcTech, Tamim Hasan
# -------------------------
# [['Java', 'Python']]
# [['Dart', 'C++']]
# Name: Tamim Hasan
# Designation: Software Engineer
# Department: Android Development
# Programming Skills: "Dart", "C++"
# Frameworks: "Express.js", "React"
# -------------------------
# Your salary for this month is Tk. 54600
# -------------------------
# -------------------------
# Welcome to abcTech, Jahin Khandoker
# -------------------------
# [['Java', 'Dart', 'Swift']]
# Name: Jahin Khandoker
# Designation: Senior Developer
# Department: App Development
# Programming Skills: "Java", "Dart", "Swift"
# Frameworks: "Flutter", "React Native", "Xamarin"
# -------------------------
# Your salary for this month is Tk. 103000
# -------------------------

# %%
# task4
class abcTech:
    def __init__(self, name, job, work):
        self.name = name
        self.job = job
        self.work = work
        self.lst = []
        self.put = []
        self.put1 = None
        self.salary = None
        self.out1 = None  
        print(f'Welcome to abcTech, {self.name}')
    def addProgrammingSkills(self, skill):
        for s in skill:
            if self.out1:
                self.out1 += f', "{s}"'
            else:
                self.out1 = f'"{s}"'
    def calculateSalary(self, salary, hours):
        if hours > 144:
            salary = salary + (hours - 144) * 800
        else:
            salary = salary
        return salary
    def addFrameworks(self,*args):
        res=''
        for j in args:
            self.put+=j
        for k in self.put:
            res+='"'+k+'"'+', '
            self.put1=res[:-2]
    def printInfo(self):
        print(f'Name: {self.name}\nDesignation: {self.job}\nDepartment: {self.work}')
        print(f'Programming Skills: {self.out1}')
        print(f'Frameworks: {self.put1}')
print("-------------------------")
b1 =abcTech("Tamim Hasan", "Software Engineer", "Android Development")
print("-------------------------")
b1.addProgrammingSkills(["Java", "Python"])
b1.addProgrammingSkills(["Dart", "C++"])
b1.addFrameworks(["Express.js", "React"])
b1.printInfo()
print("-------------------------")
print(f"Your salary for this month is Tk. {b1.calculateSalary(45000, 156)}")
print("-------------------------")
print("-------------------------")
b2 =abcTech("Jahin Khandoker", "Senior Developer", "App Development")
print("-------------------------")
b2.addProgrammingSkills(["Java", "Dart", "Swift"])
b2.addFrameworks(["Flutter", "React Native"])
b2.addFrameworks(["Xamarin"])
b2.printInfo()
print("-------------------------")
print(f"Your salary for this month is Tk. {b2.calculateSalary(103000, 123)}")
print("-------------------------")
# Out:
# -------------------------
# Welcome to abcTech, Tamim Hasan
# -------------------------
# Name: Tamim Hasan
# Designation: Software Engineer
# Department: Android Development
# Programming Skills: "Java", "Python", "Dart", "C++"
# Frameworks: "Express.js", "React"
# -------------------------
# Your salary for this month is Tk. 54600
# -------------------------
# -------------------------
# Welcome to abcTech, Jahin Khandoker
# -------------------------
# Name: Jahin Khandoker
# Designation: Senior Developer
# Department: App Development
# Programming Skills: "Java", "Dart", "Swift"
# Frameworks: "Flutter", "React Native", "Xamarin"
# -------------------------
# Your salary for this month is Tk. 103000
# -------------------------

# %%
# task5
class StudentDatabase:
    def __init__(self, name, ID):
        self.name = name
        self.id = ID
        self.grades = {}
        self.cgpa = 0
    
    def calculateGPA(self, course_cgpa_list, semester):
      course_list = []
      total_cgpa = 0 
      small_dict = {}
      
      for course in course_cgpa_list: 
        course_code, cgpa= course.split(":") 
        course_list.append(course_code)
        total_cgpa+= float(cgpa)
        self.cgcollector = total_cgpa
      average = total_cgpa/len(course_list) 
      small_dict[tuple (course_list)]=round(average, 2)
      self.grades[semester]=small_dict
      

      sum = ""
      for i in course_list:
        sum = sum + i + "\n"
        self.collector = sum
    
    def printDetails(self):
        print(f"Name: {self.name}")
        print(f"ID: {self.id}")
        for i, j in self.grades.items():
            print(f"Courses taken in {i}:")
            for k,l in j.items():
                print("\n".join(list(k)))
            print(f"GPA: {l}")

# Write your code here
s1 = StudentDatabase('Pietro', '10101222')
s1.calculateGPA(['CSE230: 4.0', 'CSE220: 4.0', 'MAT110: 4.0'], 'Summer2020')
s1.calculateGPA(['CSE250: 3.7', 'CSE330: 4.0'], 'Summer2021')
print(f'Grades for {s1.name}\n{s1.grades}')
print('---------------------------------')
s1.printDetails()
s2 = StudentDatabase('Wanda', '10103332')
s2.calculateGPA(['CSE111: 3.7', 'CSE260: 3.7', 'ENG101: 4.0'], 'Summer2022')
print('---------------------------------')
print(f'Grades for {s2.name}\n{s2.grades}')
print('---------------------------------')
s2.printDetails()
# Out:
# Grades for Pietro
# {'Summer2020': {('CSE230', 'CSE220', 'MAT110'): 4.0}, 'Summer2021': {('CSE250', 'CSE330'): 3.85}}
# ---------------------------------
# Name: Pietro
# ID: 10101222
# Courses taken in Summer2020:
# CSE230
# CSE220
# MAT110
# GPA: 4.0
# Courses taken in Summer2021:
# CSE250
# CSE330
# GPA: 3.85
# ---------------------------------
# Grades for Wanda
# {'Summer2022': {('CSE111', 'CSE260', 'ENG101'): 3.8}}
# ---------------------------------
# Name: Wanda
# ID: 10103332
# Courses taken in Summer2022:
# CSE111
# CSE260
# ENG101
# GPA: 3.8

# %%
# task6  
class Store:
    def __init__(self,balance):
        self.balacnce=balance;self.lst=[]
        self.total_items=[];self.alldict={}
        print('New branch created!')
    def viewAllItems(self):
        if len(self.total_items)<1:
            print('There are no items in your inventory')
        else:
            pass
    def viewAllItemDetails(self):
        # for i in self.items:
            # self.alldict[i]
        print(self.alldict)
    def add_item(self,lst_goods):
print("==========================")
branch1 = Store(5000)
print(f"Current Balance: {branch1.balance}")
print(f"Total items: {branch1.total_items}")
branch1.viewAllItems()
branch1.viewAllItemDetails()
print("==========================")
print(f"Current Balance: {branch1.balance}")
branch1.add_item(["ChaCha Noodles", 10, 5, 8])
print(f"Current Balance: {branch1.balance}")
branch1.add_item(["Sparrow Shampoo", 5, 10, 20])
print(f"Current Balance: {branch1.balance}")
print("==========================")
branch1.viewAllItems()
print()
branch1.viewAllItemDetails()
print()
print("==========================")
print(f"Current Balance: {branch1.balance}\n")
branch1.sell_item("ChaCha Noodles", 15)
print(f"Current Balance: {branch1.balance}\n")
branch1.viewAllItemDetails()
print()
branch1.sell_item("ChaCha Noodles", 10)
print()
print(f"Current Balance: {branch1.balance}\n")
branch1.viewAllItemDetails()
print()
print("==========================")
print(f"Current Balance: {branch1.balance}\n")
branch1.restock_item("ChaCha Noodles", 5)
print()
branch1.viewAllItemDetails()
print()
print(f"Current Balance: {branch1.balance}\n")
print("==========================")
# Out:
#   Cell In[1], line 4
#     self.items=[];alldict=
#                           ^
# SyntaxError: invalid syntax

# %%
# task6
class Store:
    def __init__(self, balance):
        self.balance = balance
        self.inventory = {}
        print("==========================")
        print("New branch created!")
        self.total_items = 0

    def add_item(self, items):
        name, stock, b_price, s_price = items
        if name in self.inventory:
            self.inventory[name]['stock'] += stock
        else:
            self.inventory[name] = {'stock': stock, 'buying_price': b_price, 'selling_price': s_price}
        self.balance -= stock * b_price
        print(f"Item added: {name}")
        # print(f"Current Balance: {self.balance}")

    def restock_item(self, item_name, stock):
        if item_name in self.inventory:
            self.inventory[item_name]['stock'] += stock
            print(f"Restocked item: {item_name}, Current Stock: {self.inventory[item_name]['stock']}")
            self.balance -= stock * self.inventory[item_name]['buying_price']
            # print(f"Current Balance: {self.balance}")

    def sell_item(self, name, quantity):
        if name in self.inventory:
            if self.inventory[name]['stock'] >= quantity:
                self.inventory[name]['stock'] -= quantity
                self.balance += quantity * self.inventory[name]['selling_price']
                # print(f"Sold {quantity} {item_name}")
                # print(f"Current Balance: {self.balance}")
            else:
                print(f"Sorry! {name} is not available at your desired quantity. Currently we have: {self.inventory[name]['stock']}")
                # print(f"Current Balance: {self.balance}")

    def viewAllItems(self):
        if not self.inventory:
            print("There are no items in your inventory")
        else:
            print("All Items:", ", ".join(self.inventory.keys()))

    def viewAllItemDetails(self):
        print(self.inventory)

# Driver Code
branch1 = Store(5000)
print(f"Current Balance: {branch1.balance}")
print(f"Total items: {branch1.total_items}")
branch1.viewAllItems()
branch1.viewAllItemDetails()
print("==========================")
print(f"Current Balance: {branch1.balance}")
branch1.add_item(["ChaCha Noodles", 10, 5, 8])
print(f"Current Balance: {branch1.balance}")
branch1.add_item(["Sparrow Shampoo", 5, 10, 20])
print(f"Current Balance: {branch1.balance}")
print("==========================")
branch1.viewAllItems()
print()
branch1.viewAllItemDetails()
print()
print("==========================")
print(f"Current Balance: {branch1.balance}\n")
branch1.sell_item("ChaCha Noodles", 15)
print(f"Current Balance: {branch1.balance}\n")
branch1.viewAllItemDetails()
print()
branch1.sell_item("ChaCha Noodles", 10)
print()
print(f"Current Balance: {branch1.balance}\n")
branch1.viewAllItemDetails()
print()
print("==========================")
print(f"Current Balance: {branch1.balance}\n")
branch1.restock_item("ChaCha Noodles", 5)
print()
branch1.viewAllItemDetails()
print()
print(f"Current Balance: {branch1.balance}\n")
print("==========================")
# Out:
# ==========================
# New branch created!
# Current Balance: 5000
# Total items: 0
# There are no items in your inventory
# {}
# ==========================
# Current Balance: 5000
# Item added: ChaCha Noodles
# Current Balance: 4950
# Item added: Sparrow Shampoo
# Current Balance: 4900
# ==========================
# All Items: ChaCha Noodles, Sparrow Shampoo
#
# {'ChaCha Noodles': {'stock': 10, 'buying_price': 5, 'selling_price': 8}, 'Sparrow Shampoo': {'stock': 5, 'buying_price': 10, 'selling_price': 20}}
#
# ==========================
# Current Balance: 4900
#
# Sorry! ChaCha Noodles is not available at your desired quantity. Currently we have: 10
# Current Balance: 4900
#
# {'ChaCha Noodles': {'stock': 10, 'buying_price': 5, 'selling_price': 8}, 'Sparrow Shampoo': {'stock': 5, 'buying_price': 10, 'selling_price': 20}}
#
#
# Current Balance: 4980
#
# {'ChaCha Noodles': {'stock': 0, 'buying_price': 5, 'selling_price': 8}, 'Sparrow Shampoo': {'stock': 5, 'buying_price': 10, 'selling_price': 20}}
#
# ==========================
# Current Balance: 4980
#
# Restocked item: ChaCha Noodles, Current Stock: 5
#
# {'ChaCha Noodles': {'stock': 5, 'buying_price': 5, 'selling_price': 8}, 'Sparrow Shampoo': {'stock': 5, 'buying_price': 10, 'selling_price': 20}}
#
# Current Balance: 4955
#
# ==========================

# %%
# task6
class Store:
    def __init__(self, balance):
        self.balance = balance
        self.inventory = {}
        print("==========================")
        print("New branch created!")
        self.total_items = 0

    def add_item(self, items):
        item_name, stock, buying_price, selling_price = items
        if item_name in self.inventory:
            self.inventory[item_name]['stock'] += stock
        else:
            self.inventory[item_name] = {'stock': stock, 'buying_price': buying_price, 'selling_price': selling_price}
        self.balance -= stock * buying_price
        print(f"Item added: {item_name}")
        print(f"Current Balance: {self.balance}")

    def restock_item(self, item_name, stock):
        if item_name in self.inventory:
            self.inventory[item_name]['stock'] += stock
            print(f"Restocked item: {item_name}, Current Stock: {self.inventory[item_name]['stock']}")
            self.balance -= stock * self.inventory[item_name]['buying_price']
            print(f"Current Balance: {self.balance}")

    def sell_item(self, item_name, quantity):
        if item_name in self.inventory:
            if self.inventory[item_name]['stock'] >= quantity:
                self.inventory[item_name]['stock'] -= quantity
                self.balance += quantity * self.inventory[item_name]['selling_price']
                print(f"Sold {quantity} {item_name}")
                print(f"Current Balance: {self.balance}")
            else:
                print(f"Sorry! {item_name} is not available at your desired quantity. Currently we have: {self.inventory[item_name]['stock']}")
                print(f"Current Balance: {self.balance}")

    def viewAllItems(self):
        if not self.inventory:
            print("There are no items in your inventory")
        else:
            print("All Items:", ", ".join(self.inventory.keys()))

    def viewAllItemDetails(self):
        print(self.inventory)

# Driver Code
branch1 = Store(5000)
print(f"Current Balance: {branch1.balance}")
print(f"Total items: {branch1.total_items}")
branch1.viewAllItems()
branch1.viewAllItemDetails()
print("==========================")
print(f"Current Balance: {branch1.balance}")
branch1.add_item(["ChaCha Noodles", 10, 5, 8])
print(f"Current Balance: {branch1.balance}")
branch1.add_item(["Sparrow Shampoo", 5, 10, 20])
print(f"Current Balance: {branch1.balance}")
print("==========================")
branch1.viewAllItems()
print()
branch1.viewAllItemDetails()
print()
print("==========================")
print(f"Current Balance: {branch1.balance}\n")
branch1.sell_item("ChaCha Noodles", 15)
print(f"Current Balance: {branch1.balance}\n")
branch1.viewAllItemDetails()
print()
branch1.sell_item("ChaCha Noodles", 10)
print()
print(f"Current Balance: {branch1.balance}\n")
branch1.viewAllItemDetails()
print()
print("==========================")
print(f"Current Balance: {branch1.balance}\n")
branch1.restock_item("ChaCha Noodles", 5)
print()
branch1.viewAllItemDetails()
print()
print(f"Current Balance: {branch1.balance}\n")
print("==========================")
# Out:
# ==========================
# New branch created!
# Current Balance: 5000
# Total items: 0
# There are no items in your inventory
# {}
# ==========================
# Current Balance: 5000
# Item added: ChaCha Noodles
# Current Balance: 4950
# Current Balance: 4950
# Item added: Sparrow Shampoo
# Current Balance: 4900
# Current Balance: 4900
# ==========================
# All Items: ChaCha Noodles, Sparrow Shampoo
#
# {'ChaCha Noodles': {'stock': 10, 'buying_price': 5, 'selling_price': 8}, 'Sparrow Shampoo': {'stock': 5, 'buying_price': 10, 'selling_price': 20}}
#
# ==========================
# Current Balance: 4900
#
# Sorry! ChaCha Noodles is not available at your desired quantity. Currently we have: 10
# Current Balance: 4900
# Current Balance: 4900
#
# {'ChaCha Noodles': {'stock': 10, 'buying_price': 5, 'selling_price': 8}, 'Sparrow Shampoo': {'stock': 5, 'buying_price': 10, 'selling_price': 20}}
#
# Sold 10 ChaCha Noodles
# Current Balance: 4980
#
# Current Balance: 4980
#
# {'ChaCha Noodles': {'stock': 0, 'buying_price': 5, 'selling_price': 8}, 'Sparrow Shampoo': {'stock': 5, 'buying_price': 10, 'selling_price': 20}}
#
# ==========================
# Current Balance: 4980
#
# Restocked item: ChaCha Noodles, Current Stock: 5
# Current Balance: 4955
#
# {'ChaCha Noodles': {'stock': 5, 'buying_price': 5, 'selling_price': 8}, 'Sparrow Shampoo': {'stock': 5, 'buying_price': 10, 'selling_price': 20}}
#
# Current Balance: 4955
#
# ==========================

# %%
# task7
class Scope:
    def __init__(self):
        self.x, self.y, self.z = 1, 8, [1,2,3]   
    def met1(self):
        x = 3
        x = self.x + self.z[2] + self.met2(self.z[0])
        self.y = self.y + self.x + 5
        self.z[2] = self.y + self.met2(3) + self.y
        print(x, self.y, self.z[2])         
    def met2(self,x):
        y = x + self.z[0]
        print(self.x, y, self.z[1])
        self.x = self.x + y + self.z[1]
        self.y = self.y + 13
        self.z[1] = y + self.y
        return self.x + y


q2 = Scope()
q2.met1()
q2.met2(8)
q1=q2
q2.met2(5)
# Out:
# 1 2 2
# 5 4 23
# 11 44 111
# 32 9 48
# 89 6 66
# 167

# %%
# task8
class Test7:
  def __init__(self):
      self.sum = 0
      self.y = 0
  def methodA(self):   
      x=y=k=0
      msg = [5]  
      while (k < 2):
          y += msg[0]     
          x = y + self.methodB(msg, k)
          self.sum = x + y + msg[0]
          print(x ," " , y, " " , self.sum)
          k+=1 
  def methodB(self, mg2, mg1):
        x = 0
        self.y += mg2[0]
        x = x + 3 + mg1
        self.sum += x + self.y
        mg2[0] = self.y + mg1
        mg1 += x + 2
        print(x , " " ,self.y, " " , self.sum)
        return mg1
t1 = Test7()
t1.methodA()
t1.methodA()
# Out:
# 3   5   8
# 10   5   20
# 4   10   34
# 17   10   38
# 3   15   56
# 10   5   30
# 4   30   64
# 27   20   78

# %%
lst='Asus_China','Vivo_Bangladesh','Sony_India','Lenevo_China'
tup=(60000,30000,80000,55000)
dict1={}
res=[]
div=[]
dict2={}
for i in lst:
    out=i.split('_')
    for j in tup:
        dict1[out[0]]=j
    div.append(out[1])
    if out[1]=='China':
        res.append('no')
    else:
        res.append('ok')
    # print(out)
print(f'{dict1}')
# print(dict2)
print(div)
print(res)
# print(res)
# Out:
# {'Asus': 55000, 'Vivo': 55000, 'Sony': 55000, 'Lenevo': 55000}
# ['China', 'Bangladesh', 'India', 'China']
# ['no', 'ok', 'ok', 'no']

# %%
class StudentDatabase:
    def __init__(self,name,id):
        self.name=name;self.id=id;self.grades={}
        self.cg=0
    def calculateGPA(self,lst,sem):
        course_lst=[];total_cg=0;dict1={}
        for i in lst:
            sub,cg=i.split(':')
            course_lst.append(sub)
            total_cg+=float(cg)
            self.cg=total_cg
        avg=total_cg/len(course_lst)
        dict1[tuple(course_lst)]=round(avg,2)
        # print(dict1)
        self.grades[sem]=dict1
        # print(self.grades)
    def printDetails(self):
        print(f'Name: {self.name}\nID: {self.id}')
        for i,j in self.grades.items():
            print(f'Courses taken in {i}')
            for k,v in j.items():
                out='\n'.join(k)
                print(out)
            print(f'GPA: {v}')
# Write your code here
s1 = StudentDatabase('Pietro', '10101222')
s1.calculateGPA(['CSE230: 4.0', 'CSE220: 4.0', 'MAT110: 4.0'], 'Summer2020')
s1.calculateGPA(['CSE250: 3.7', 'CSE330: 4.0'], 'Summer2021')
print(f'Grades for {s1.name}\n{s1.grades}')
print('---------------------------------')
s1.printDetails()
s2 = StudentDatabase('Wanda', '10103332')
s2.calculateGPA(['CSE111: 3.7', 'CSE260: 3.7', 'ENG101: 4.0'], 'Summer2022')
print('---------------------------------')
print(f'Grades for {s2.name}\n{s2.grades}')
print('---------------------------------')
s2.printDetails()
# Out:
# Grades for Pietro
# {'Summer2020': {('CSE230', 'CSE220', 'MAT110'): 4.0}, 'Summer2021': {('CSE250', 'CSE330'): 3.85}}
# ---------------------------------
# Name: Pietro
# ID: 10101222
# Courses taken in Summer2020
# CSE230
# CSE220
# MAT110
# GPA: 4.0
# Courses taken in Summer2021
# CSE250
# CSE330
# GPA: 3.85
# ---------------------------------
# Grades for Wanda
# {'Summer2022': {('CSE111', 'CSE260', 'ENG101'): 3.8}}
# ---------------------------------
# Name: Wanda
# ID: 10103332
# Courses taken in Summer2022
# CSE111
# CSE260
# ENG101
# GPA: 3.8

# %%
class Store:
    def __init__(self,balance):
        self.balance=balance;self.total=0
        print('New branch created!')
    def add_item(self,lst):
        
print("==========================")
branch1 = Store(5000)
print(f"Current Balance: {branch1.balance}")
print(f"Total items: {branch1.total_items}")
branch1.viewAllItems()
branch1.viewAllItemDetails()
print("==========================")
print(f"Current Balance: {branch1.balance}")
branch1.add_item(["ChaCha Noodles", 10, 5, 8])
print(f"Current Balance: {branch1.balance}")
branch1.add_item(["Sparrow Shampoo", 5, 10, 20])
print(f"Current Balance: {branch1.balance}")
print("==========================")
branch1.viewAllItems()
print()
branch1.viewAllItemDetails()
print()
print("==========================")
print(f"Current Balance: {branch1.balance}\n")
branch1.sell_item("ChaCha Noodles", 15)
print(f"Current Balance: {branch1.balance}\n")
branch1.viewAllItemDetails()
print()
branch1.sell_item("ChaCha Noodles", 10)
print()
print(f"Current Balance: {branch1.balance}\n")
branch1.viewAllItemDetails()
print()
print("==========================")
print(f"Current Balance: {branch1.balance}\n")
branch1.restock_item("ChaCha Noodles", 5)
print()
branch1.viewAllItemDetails()
print()
print(f"Current Balance: {branch1.balance}\n")
print("==========================")

# %%
# 'a: 100, b: 100, c: 200, d: 300'
# 'a: 300, b: 200, d: 400, e: 200'
str1=input().split(', ')
str2=input().split(', ')
dict1={};lst=[]
for i in str1:
    i=i.split(':')
    dict1[i[0]]=int(i[1])
# print(dict1)
for i in str2:
    i=i.split(':')
    if i[0] not in dict1.keys():
        dict1[i[0]]=int(i[1])
    else:
        dict1[i[0]]+=int(i[1])
print(dict1)
for v in dict1.values():
    if v not in lst:
        lst.append(int(v))
lst=tuple(sorted(lst))
print(f'Values: {lst}')
# Out:
# {'a': 400, 'b': 300, 'c': 200, 'd': 700, 'e': 200}
# Values: (200, 300, 400, 700)

# %%
dict1={}
while True:
    var1=input()
    if var1=='STOP':
        break
    var2=int(var1)
    if var1 not in dict1:
        dict1[var1]=1
    else:
        dict1[var1]+=1
for k,v in dict1.items():
    print(f'{k} - {str(v)} times')
# Out:
# 10 - 2 times
# 20 - 2 times
# 30 - 1 times
# 50 - 1 times
# 80 - 1 times

# %%
# var='key1 : value1, key2 : value2, key3 : value1'
var=input().split(', ')
dict1={};lst=[]
# var1=var.split(', ')
for i in var:
    out=i.split(' : ')
    print(out)
    print(i)
    if out[1] in dict1.keys():
        dict1[out[1]]+=[out[0]]
    else:
        dict1[out[1]]=[out[0]]
print(dict1)
# Out:
# ['key1', 'value1']
# key1 : value1
# ['key2', 'value2']
# key2 : value2
# ['key3', 'value1']
# key3 : value1
# {'value1': ['key1', 'key3'], 'value2': ['key2']}
