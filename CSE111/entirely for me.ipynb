# %%
def key_generator(*lst):
    out='';code=''
    str1='';str2=''
    em=[];me=[]
    for i in lst:
        str1=i[0]
        str2=i[-1]
        if str1.isupper():
            str1=str1.lower()
        else:
            str1=str1.upper()
        if str2.isupper():
            str2=str2.lower()
        else:
            str2=str2.upper()
        # print(str1,str2)
        out=i[1:-1]
        # code+=ord(out)
        em.append(out)
        middle=[]
        for j in i[::-1]:
            middle.append(str(ord(j)))
        # put=(','.join(me))
        # print(ord(j))
    print(code)
    print(em)
    print(me)
    # print(put)
    print(middle)
key_generator('Alex','Bob','Trudy')
# Out:
# ['le', 'o', 'rud']
# []
# ['121', '100', '117', '114', '84']

# %%
class Sphere:
    def __init__(self,name,rad=1,color='White'):
        self.name=name;self.rad=rad;self.color=color
        self.volume=(4/3)*(3.1416*(rad**3))
    def printDetails(self):
        print(f'Sphere ID: {self.name}\nColor: {self.color}\nVolume: {self.volume}')
    def merge_sphere(self, *spheres):
        total_volume = self.volume
        mixed_color = False

        for sphere in spheres:
            total_volume += sphere.volume

            if sphere.color != self.color:
                mixed_color = True
        print('Spheres are being merged')
        self.radius = ((3/4 * total_volume) / 3.1416) ** (1/3)
        self.volume = total_volume

        if mixed_color:
            self.color = "Mixed Color"
        else:
            self.color = self.color

#Write your code here
sphere1 = Sphere("Sphere 1")
print("1***************")
sphere1.printDetails()
print("2***************")
sphere2 = Sphere("Sphere 2", 3)
print("3***************")
sphere2.printDetails()
print("4***************")
sphere3 = Sphere("Sphere 3", 2)
print("5***************")
sphere3.printDetails()
print("6***************")
sphere3.merge_sphere(sphere1,sphere2)
print("7***************")
sphere3.printDetails()
print("8***************")
sphere4 = Sphere("Sphere 4", 5, "Purple")
print("9***************")
sphere4.merge_sphere(sphere3)
print("10***************")
sphere4.printDetails()
# Out:
# 1***************
# Sphere ID: Sphere 1
# Color: White
# Volume: 4.1888
# 2***************
# 3***************
# Sphere ID: Sphere 2
# Color: White
# Volume: 113.0976
# 4***************
# 5***************
# Sphere ID: Sphere 3
# Color: White
# Volume: 33.5104
# 6***************
# Spheres are being merged
# 7***************
# Sphere ID: Sphere 3
# Color: White
# Volume: 150.7968
# 8***************
# 9***************
# Spheres are being merged
# 10***************
# Sphere ID: Sphere 4
# Color: Mixed Color
# Volume: 674.3967999999999

# %%
class Shopidify:
    def __init__(self,name='Guest'):
        self.name=name
        self.dict1={};self.lst=[]
    def add_to_cart(self,*goods):
        dict1={}
        for i in goods:
            act_good=goods[0];num=goods[1]
            for j in goods:
                dict1[i[0]]=j
            # act_good=i[0];num=i[1]
            # # print(act_good,num)
        #     self.lst.append(i)
        # print(self.lst)
        print(dict1)
# Test the Shopidify class
guest_account = Shopidify()
print("1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account = Shopidify("John")
print("2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan", 2)
guest_account.add_to_cart("Luffy Action Figure")
guest_account.display_cart()
print("3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.add_to_cart(["Chocolate Chip Cookies", 3,"Goku Action Figure",2,"Dumbbells-5kg",2])
john_account.display_cart()
print("4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan")
guest_account.display_cart()
print("5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.checkout()
print("6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.display_history()
print("7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.checkout()
print("8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.display_history()
print("9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
# Out:
# 1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\code code code\entirely for me.ipynb Cell 3 line 2
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/entirely%20for%20me.ipynb#W2sZmlsZQ%3D%3D?line=18'>19</a> john_account = Shopidify("John")
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/entirely%20for%20me.ipynb#W2sZmlsZQ%3D%3D?line=19'>20</a> print("2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
# ---> <a href='vscode-notebook-cell:/d%3A/code%20code%20code/entirely%20for%20me.ipynb#W2sZmlsZQ%3D%3D?line=20'>21</a> guest_account.add_to_cart("Air Jordan", 2)
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/entirely%20for%20me.ipynb#W2sZmlsZQ%3D%3D?line=21'>22</a> guest_account.add_to_cart("Luffy Action Figure")
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/entirely%20for%20me.ipynb#W2sZmlsZQ%3D%3D?line=22'>23</a> guest_account.display_cart()
#
# d:\code code code\entirely for me.ipynb Cell 3 line 1
#       <a href='vscode-notebook-cell:/d%3A/code%20code%20code/entirely%20for%20me.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a>     act_good=goods[0];num=goods[1]
#       <a href='vscode-notebook-cell:/d%3A/code%20code%20code/entirely%20for%20me.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a>     for j in goods:
# ---> <a href='vscode-notebook-cell:/d%3A/code%20code%20code/entirely%20for%20me.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a>         dict1[i[0]]=j
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/entirely%20for%20me.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a>     # act_good=i[0];num=i[1]
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/entirely%20for%20me.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a>     # # print(act_good,num)
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/entirely%20for%20me.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a> #     self.lst.append(i)
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/entirely%20for%20me.ipynb#W2sZmlsZQ%3D%3D?line=13'>14</a> # print(self.lst)
#      <a href='vscode-notebook-cell:/d%3A/code%20code%20code/entirely%20for%20me.ipynb#W2sZmlsZQ%3D%3D?line=14'>15</a> print(dict1)
#
# TypeError: 'int' object is not subscriptable

# %%
class Shopidify:
    def __init__(self, username=None):
        self.username = username if username else "Guest"
        self.cart = {}
        self.history = []
        self.transaction_number = 1

        if self.username == "Guest":
            print("Welcome to Shopidify 1")
        else:
            print(f"Welcome {self.username} to Shopidify 2")

    def add_to_cart(self, *items):
        for item in items:
            if item not in self.cart:
                self.cart[item] = 1
            else:
                self.cart[item] += 1

    def display_cart(self):
        print(f"Items in the cart for {self.username}:")
        for item, quantity in self.cart.items():
            print(f"- {item}: {quantity}x")

    def checkout(self):
        print(f"Checkout completed for {self.username}")
        self.history.append(f"Transaction {self.transaction_number}:")
        for item, quantity in self.cart.items():
            self.history.append(f"- {item}: {quantity}x")
        self.cart = {}
        self.transaction_number += 1

    def display_history(self):
        print(f"Purchase history for {self.username}:")
        for transaction in self.history:
            print(transaction)


# Test the Shopidify class
guest_account = Shopidify()
print("1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account = Shopidify("John")
print("2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan", 2)
guest_account.add_to_cart("Luffy Action Figure")
guest_account.display_cart()
print("3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.add_to_cart("Chocolate Chip Cookies", 3, "Goku Action Figure", 2, "Dumbbells-5kg", 2)
john_account.display_cart()
print("4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan")
guest_account.display_cart()
print("5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.checkout()
print("6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.display_history()
print("7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.checkout()
print("8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.display_history()
print("9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
# Out:
# Welcome to Shopidify 1
# 1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Welcome John to Shopidify 2
# 2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for Guest:
# - Air Jordan: 1x
# - 2: 1x
# - Luffy Action Figure: 1x
# 3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for John:
# - Chocolate Chip Cookies: 1x
# - 3: 1x
# - Goku Action Figure: 1x
# - 2: 2x
# - Dumbbells-5kg: 1x
# 4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for Guest:
# - Air Jordan: 2x
# - 2: 1x
# - Luffy Action Figure: 1x
# 5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Checkout completed for Guest
# 6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Purchase history for Guest:
# Transaction 1:
# - Air Jordan: 2x
# - 2: 1x
# - Luffy Action Figure: 1x
# 7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Checkout completed for John
# 8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Purchase history for John:
# Transaction 1:
# - Chocolate Chip Cookies: 1x
# - 3: 1x
# - Goku Action Figure: 1x
# - 2: 2x
# - Dumbbells-5kg: 1x
# 9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
class Shopidify:
    def __init__(self, username=None):
        self.username = username if username else "Guest"
        self.cart = {}
        self.history = []
        self.transaction_number = 1

        if self.username == "Guest":
            print("Welcome to Shopidify 1")
        else:
            print(f"Welcome {self.username} to Shopidify 2")

    def add_to_cart(self, *items):
        for item in items:
            if isinstance(item, list):
                for i in range(0, len(item), 2):
                    product = item[i]
                    quantity = item[i + 1] if i + 1 < len(item) else 1
                    if product not in self.cart:
                        self.cart[product] = quantity
                    else:
                        self.cart[product] += quantity
            else:
                if item not in self.cart:
                    self.cart[item] = 1
                else:
                    self.cart[item] += 1


    def display_cart(self):
        print(f"Items in the cart for {self.username}:")
        for item, quantity in self.cart.items():
            print(f"- {item}: {quantity}x")

    def checkout(self):
        print(f"Checkout completed for {self.username}")
        self.history.append(f"Transaction {self.transaction_number}:")
        for item, quantity in self.cart.items():
            self.history.append(f"- {item}: {quantity}x")
        self.cart = {}
        self.transaction_number += 1

    def display_history(self):
        print(f"Purchase history for {self.username}:")
        for transaction in self.history:
            print(transaction)


# Test the Shopidify class
guest_account = Shopidify()
print("1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account = Shopidify("John")
print("2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan", 2)
guest_account.add_to_cart("Luffy Action Figure")
guest_account.display_cart()
print("3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.add_to_cart("Chocolate Chip Cookies", 3, "Goku Action Figure", 2, "Dumbbells-5kg", 2)
john_account.display_cart()
print("4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan")
guest_account.display_cart()
print("5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.checkout()
print("6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.display_history()
print("7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.checkout()
print("8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.display_history()
print("9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
# Out:
# Welcome to Shopidify 1
# 1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Welcome John to Shopidify 2
# 2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for Guest:
# - Air Jordan: 1x
# - 2: 1x
# - Luffy Action Figure: 1x
# 3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for John:
# - Chocolate Chip Cookies: 1x
# - 3: 1x
# - Goku Action Figure: 1x
# - 2: 2x
# - Dumbbells-5kg: 1x
# 4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for Guest:
# - Air Jordan: 2x
# - 2: 1x
# - Luffy Action Figure: 1x
# 5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Checkout completed for Guest
# 6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Purchase history for Guest:
# Transaction 1:
# - Air Jordan: 2x
# - 2: 1x
# - Luffy Action Figure: 1x
# 7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Checkout completed for John
# 8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Purchase history for John:
# Transaction 1:
# - Chocolate Chip Cookies: 1x
# - 3: 1x
# - Goku Action Figure: 1x
# - 2: 2x
# - Dumbbells-5kg: 1x
# 9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
class Shopidify:
    def __init__(self, username=None):
        self.username = username if username else "Guest"
        self.cart = {}
        self.history = []
        self.transaction_number = 1

        if self.username == "Guest":
            print("Welcome to Shopidify 1", end=" ")
        else:
            print(f"Welcome {self.username} to Shopidify 2")

    def add_to_cart(self, *items):
        for item in items:
            if type(item) == list:
                for i in range(0, len(item), 2):
                    product = item[i]
                    quantity = item[i + 1] if i + 1 < len(item) else 1
                    self.cart[product] = self.cart.get(product, 0) + quantity
            else:
                self.cart[item] = self.cart.get(item, 0)

    def display_cart(self):
        print(f"Items in the cart for {self.username}:")
        for item, quantity in self.cart.items():
            print(f"- {item}: {quantity}x")

    def checkout(self):
        print(f"Checkout completed for {self.username}")
        self.history.append(f"Transaction {self.transaction_number}:")
        for item, quantity in self.cart.items():
            self.history.append(f"- {item}: {quantity}x")
        self.cart = {}
        self.transaction_number += 1

    def display_history(self):
        print(f"Purchase history for {self.username}:")
        for transaction in self.history:
            print(transaction)

# Test the Shopidify class
guest_account = Shopidify()
print("1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account = Shopidify("John")
print("2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan", 2)
guest_account.add_to_cart("Luffy Action Figure")
guest_account.display_cart()
print("3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.add_to_cart(["Chocolate Chip Cookies", 3, "Goku Action Figure", 2, "Dumbbells-5kg", 2])
john_account.display_cart()
print("4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan")
guest_account.display_cart()
print("5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.checkout()
print("6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.display_history()
print("7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.checkout()
print("8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.display_history()
print("9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
# Out:
# Welcome to Shopidify 1 1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Welcome John to Shopidify 2
# 2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for Guest:
# - Air Jordan: 0x
# - 2: 0x
# - Luffy Action Figure: 0x
# 3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for John:
# - Chocolate Chip Cookies: 3x
# - Goku Action Figure: 2x
# - Dumbbells-5kg: 2x
# 4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for Guest:
# - Air Jordan: 0x
# - 2: 0x
# - Luffy Action Figure: 0x
# 5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Checkout completed for Guest
# 6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Purchase history for Guest:
# Transaction 1:
# - Air Jordan: 0x
# - 2: 0x
# - Luffy Action Figure: 0x
# 7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Checkout completed for John
# 8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Purchase history for John:
# Transaction 1:
# - Chocolate Chip Cookies: 3x
# - Goku Action Figure: 2x
# - Dumbbells-5kg: 2x
# 9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
class Shopidify:
    def __init__(self, user=None):
        self.user = user
        self.cart = {}
        self.history = []
        print("Welcome to Shopidify" + (" " + str(user) if user else ""))

    def add_to_cart(self, *items):
        for item in items:
            if isinstance(item, list):
                for i in range(0, len(item), 2):
                    product = item[i]
                    quantity = item[i + 1] if i + 1 < len(item) else 1
                    if product in self.cart:
                        self.cart[product] += quantity
                    else:
                        self.cart[product] = quantity
            else:
                if item in self.cart:
                    self.cart[item] += 1
                else:
                    self.cart[item] = 1
        if self.user is None:
            print("Items added to the cart for Guest:")
        else:
            print(f"Items added to the cart for {self.user}:")


    def display_cart(self):
        if self.user:
            print(f"Items in the cart for {self.user}:")
        else:
            print("Items in the cart for Guest:")
        for product, quantity in self.cart.items():
            print(f"- {product}: {quantity}x")

    def checkout(self):
        transaction = {}
        for product, quantity in self.cart.items():
            transaction[product] = quantity
        self.history.append(transaction)
        print("Checkout completed" + (" for " + self.user if self.user else ""))

    def display_history(self):
        if self.user:
            print(f"Purchase history for {self.user}:")
        else:
            print("Purchase history for Guest:")
        for i, transaction in enumerate(self.history, 1):
            print(f"Transaction {i}:")
            for product, quantity in transaction.items():
                print(f"- {product}: {quantity}x")


# Test the Shopidify class
guest_account = Shopidify()
print("1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account = Shopidify("John")
print("2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan", 2)
guest_account.add_to_cart("Luffy Action Figure")
guest_account.display_cart()
print("3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.add_to_cart(["Chocolate Chip Cookies", 3, "Goku Action Figure", 2, "Dumbbells-5kg", 2])
john_account.display_cart()
print("4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan")
guest_account.display_cart()
print("5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.checkout()
print("6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.display_history()
print("7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.checkout()
print("8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.display_history()
print("9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
# Out:
# Welcome to Shopidify
# 1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Welcome to Shopidify John
# 2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items added to the cart for Guest:
# Items added to the cart for Guest:
# Items in the cart for Guest:
# - Air Jordan: 1x
# - 2: 1x
# - Luffy Action Figure: 1x
# 3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items added to the cart for John:
# Items in the cart for John:
# - Chocolate Chip Cookies: 3x
# - Goku Action Figure: 2x
# - Dumbbells-5kg: 2x
# 4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items added to the cart for Guest:
# Items in the cart for Guest:
# - Air Jordan: 2x
# - 2: 1x
# - Luffy Action Figure: 1x
# 5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Checkout completed
# 6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Purchase history for Guest:
# Transaction 1:
# - Air Jordan: 2x
# - 2: 1x
# - Luffy Action Figure: 1x
# 7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Checkout completed for John
# 8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Purchase history for John:
# Transaction 1:
# - Chocolate Chip Cookies: 3x
# - Goku Action Figure: 2x
# - Dumbbells-5kg: 2x
# 9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
